# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "hieroglyph.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])
# Out:
# {
#     "success": {
#         "total": 1
#     },
#     "contents": {
#         "quotes": [
#             {
#                 "quote": "Climb the mountains and get their good tidings. Nature's peace will flow into you as sunshine flows into trees. The winds will blow their own freshness into you, and the storms their energy, while cares will drop away from you like the leaves of Autumn.",
#                 "length": "253",
#                 "author": "John Muir",
#                 "tags": [
#                     "autumn",
#                     "inspire",
#                     "mountaineering",
#                     "peace",
#                     "tso-life"
#                 ],
#                 "category": "inspire",
#                 "date": "2017-09-11",
#                 "permalink": "https://theysaidso.com/quote/AplDeYJXEVuZ8_Qsl4d7QweF/john-muir-climb-the-mountains-and-get-their-good-tidings-natures-peace-will-flow",
#                 "title": "Inspiring Quote of the day",
#                 "background": "https://theysaidso.com/img/bgs/man_on_the_mountain.jpg",
#                 "id": "AplDeYJXEVuZ8_Qsl4d7QweF"
#             }
#         ],
#         "copyright": "2017-19 theysaidso.com"
#     }
# }
# Climb the mountains and get their good tidings. Nature's peace will flow into you as sunshine flows into trees. The winds will blow their own freshness into you, and the storms their energy, while cares will drop away from you like the leaves of Autumn.
# -- John Muir

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://www.udacity.com/courses/all")
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta name="csrf-param" content="authenticity_token" />
# <meta name="csrf-token" content="0pBja+693KqE3y/mN1drRGtfRgWOnuih8qhuNQUXht7cZNB+FzR7m0x3j77d0H2/JTp8WKrsIZtbjm++X4urxw==" />
#
#   <title>All Courses and Nanodegree Programs | Udacity</title>
#
#   <link rel="canonical" href="https://www.udacity.com/courses/all" />
#
#
#
#   <meta name="google-site-verification" content="2EIknjtmPaA5nE7j3noLXPah_x_bM2bFEHZRdqSYYMk"/>
#   <meta name="google-site-verification" content="ELX2btu3VElBKIdvkGj5ESBnJh_Dg9PnWjuCwVkPEkA"/>
#
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"2059d2614a","applicationID":"12625862","transactionName":"dwpcEUoOXlUHSkxMF1UGWRYXElpWFQ==","queueTime":0,"applicationTime":166,"agent":""}</script>
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"XQAAV1JWGwICUlNXDwcF"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,n,e)])}catch(s){try{i("ierr",[s,c.now(),!0])}catch(u){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t){i("err",[t,c.now()])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=window.onerror,u=!1,d=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),u=!0)}s.on("fn-start",function(t,n,e){u&&(d+=1)}),s.on("fn-err",function(t,n,e){u&&(this.thrown=!0,o(e))}),s.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pus ...
#   <meta http-equiv="X-UA-Compatible" content="requiresActiveX=true"/>
#   <meta name="application-name" content="Udacity"/>
#   <meta name="msapplication-TileColor" content="#FFFFFF"/>
#   <meta name="msapplication-TileImage" content="https://d125fmws0bore1.cloudfront.net/assets/udacity_share-317a7f82552763598a5c91e1550b7cd83663ce02d6d475d703e25a873cd3b574.png"/>
#   <meta name="msvalidate.01" content="4ADB80ADF9A5138C8BE3B23EE428B306"/>
#   <meta name="theme-color" content="#294860">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#
#   <link rel="shortcut icon" href="https://d125fmws0bore1.cloudfront.net/assets/favicon-3867f43151ecbff486335ae6a96d17d91d6169d20888131b4681d15b65e1425b.ico"/>
#   <link rel="icon" sizes="any" mask href="https://d125fmws0bore1.cloudfront.net/assets/udacity_apple_icon-b2fe0e8bc834963f1cf490fdc55bc3170b37f05374e1e4b383af1d755d1893db.png">
#   <link rel="apple-touch-icon" href="https://d125fmws0bore1.cloudfront.net/assets/udacity_apple_icon-b2fe0e8bc834963f1cf490fdc55bc3170b37f05374e1e4b383af1d755d1893db.png">
#
#
#   <meta property="og:image:height" content="630">
#   <meta property="og:image:width" content="1200">
#   <meta property="og:image" content="https://d125fmws0bore1.cloudfront.net/assets/udacity_share-317a7f82552763598a5c91e1550b7cd83663ce02d6d475d703e25a873cd3b574.png">
#   <meta property="og:title" content="All Courses and Nanodegree Programs | Udacity">
#   <meta property="og:type" content="website">
#   <meta property="og:url" content="/courses/all">
#
#
#   <meta name="twitter:image:src" content="https://d125fmws0bore1.cloudfront.net/assets/udacity_share-317a7f82552763598a5c91e1550b7cd83663ce02d6d475d703e25a873cd3b574.png">
#   <meta name="twitter:title" content="All Courses and Nanodegree Programs | Udacity">
#   <meta name="twitter:card" content="summary_large_image">
#   <meta name="twitter:site" content="@udacity">
#   <meta name="twitter:creator" content="@udacity">
#
# <script type="text/javascript">
#   !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","page","once","off","on"];analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);analytics.push(e);return analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t){var e=document.createElement("script");e.type="text/javascript";e.async=!0;e.src=("https:"===document.location.protocol?"https://":"http://")+"cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(e,n)};analytics.SNIPPET_VERSION="3.1.0";
#       analytics.load('oP3ZXzj7KM9lvyAXexoorjH0YbvawAKg');
#       analytics.page(
#         "Catalog",
#         "Catalog - All",
#         {},
#         {}
#       );
#   }}();
# </script>
# <!--Second Google analytic account setup-->
# <script>
#   analytics.ready(function(){
#     ga('create', 'UA-28524234-29', 'auto', {'name': 'optimizeTracker'});
#     ga('optimizeTracker.require', 'GTM-MDRX326');
#     ga('optimizeTracker.send', 'pageview');
#   });
#   analytics.on('track', function(event, properties, options){
#   // custom logic based on event properties
#     ga('optimizeTracker.send', {
#         hitType: 'event',
#         eventCategory: properties.category || 'All',
#         eventAction: event,
#         eventLabel: properties.label || 'All',
#         nonInteraction: true
#     })
#   });
# </script>
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.12.2/jquery.min.js" integrity="sha256-lZFHibXzMHo3GGeehn1hudTAP3Sc0uKXBXAzHX1sjtk=" crossorigin="anonymous"></script>
# <script type="text/javascript">
#   if (!window.jQuery) {
#     var s = document.createElement('script');
#     s.src = '/public/vendor/jquery-1.12.2.min.js';
#     document.body.append(s);
#   }
# </script>
# <script src="//cdn.optimizely.com/js/655050218.js"></script>
#
#   <link href="//netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link rel="stylesheet" media="all" href="https://d125fmws0bore1.cloudfront.net/assets/legacy/legacy-325dd9cb26f17e4c94ccde8d6393c5a3e8c8e46804525d281a1a999e4f9c115d.css" />
#     <link rel="stylesheet" media="screen" href="https://d125fmws0bore1.cloudfront.net/assets/legacy/standalone/catalog-d041abc02a833132dd5c077e77ded663ccbc989528349f00edbdcfb9cfeedc79.css" />
#     <script type="application/ld+json">
#     {}
#   </script>
#
#
# </head>
# <body class="page-legacy-catalog">
#   <header class="header__sidenav slideout-menu" id="nav--mobile">
#   <div class="header__sidenav--logo">
#     <a id="ga-d16e58" title="Udacity" class="logo-link" href="/">
#       <div class="logo-wordmark">
#         <svg xmlns="http://www.w3.org/2000/svg" width="180" height="30" viewbox="0 0 180 30" alt="Udacity">
#   <g fill="none" fill-rule="evenodd">
#     <path id="wordmark" fill="#2E3D49" d="M57.6 17.239187c0 2.546698-2.085517 4.407747-4.965517 4.407747-2.88 0-4.965517-1.86105-4.965517-4.407747V7.835994H45.68276v9.501143c0 3.330298 2.88 6.170846 6.951723 6.170846 4.071724 0 6.951724-2.938498 6.951724-6.170846V7.835994H57.6v9.403193zm16.286897-9.403193h-5.36276v15.67199h5.36276c4.468965 0 7.547586-3.03645 7.547586-7.835996 0-4.701596-3.07862-7.835994-7.547586-7.835994zm-.19862 13.71299h-3.177932V9.794994h3.17793c3.376553 0 5.76 2.252847 5.76 5.876994 0 3.917998-2.482757 5.779046-5.76 5.876996zm43.49793.29385c-3.575172 0-5.95862-2.644648-5.95862-6.170846 0-3.526197 2.482758-6.072895 5.95862-6.072895 2.78069 0 4.468966 1.5672 4.468966 1.5672l.794483-1.3713s-1.787587-1.86105-5.46207-1.86105c-4.766896 0-7.746206 3.526198-7.746206 7.738045 0 4.309797 3.07862 7.933945 7.944827 7.933945 3.773793 0 5.66069-2.5467 5.66069-2.5467l-1.092414-1.175398c-.09931-.09795-1.588965 1.959-4.568276 1.959zm14.896553-14.00684h1.986206v15.67199h-1.986207zm10.924137 1.959h4.965517v13.71299h1.986207V9.794994h4.96552v-1.959H143.0069m30.587583 0l-4.766896 7.150344-4.866207-7.150347h-2.085518l5.95862 8.717546v6.954445h1.986208v-6.954444l5.85931-8.71754m-81.434482 0l-6.157242 15.67199h1.986207l1.688276-4.5057 6.45517-1.3713 2.18483 5.876998h1.986203l-6.05793-15.67199h-2.085518zm-1.886897 9.305242l2.97931-7.248294h.099315L97.92 16.063788l-5.56138 1.07745z"></path>
#     <path id="mark" fill="#02B3E4" d="M29 .5l1 .5v13c0 5.551887-2.8897 8.695692-5.995216 10.099885L24.0094 24.1l-7.620963 4.388562c-.05877.03456-.11776.068527-.176957.101902l-.08642.049764.001806-.00254C14.48289 29.545895 12.684682 30 11 30 6 30 0 26 0 18V6l2 1v11c0 8 6 10 9 10 1.858706 0 4.86901-.76773 6.89043-3.254517C14.181726 23.872636 10 20.678703 10 14V2.2L2 7 0 6l10-6 1 .5 1 .5v13c0 6.939958 4.515283 8.612086 7.017542 8.933368C19.625786 21.62159 20 19.997902 20 18V5l2 1v12c0 1.852645-.321777 3.49077-.878395 4.91438C23.648223 22.549217 28 20.813144 28 14V2.25L22 6l-2-1 8-5 1 .5z"></path>
#   </g>
# </svg>
#
#       </div>
# </a>  </div>
#   <nav class="header__sidenav--navigation" role="navigation">
#     <ul>
#       <li>
#         <a id="ga-7aee3d" title="Explore" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Pathfinder - Explore" data-cta-message="Explore" data-cta-type="link" data-cta-destination="self" data-cta-location="HomePage" href="/pathfinder">Explore</a>
#       </li>
#       <li>
#         <a id="ga-9984c5" title="Nanodegree" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Nanodegree - Nanodegree" data-cta-message="Nanodegree" data-cta-type="link" data-cta-destination="self" data-cta-location="HomePage" href="/nanodegree">Nanodegree</a>
#       </li>
#       <li>
#         <a id="ga-0dc7f9" title="Catalog" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Catalog - Catalog" data-cta-message="Catalog" data-cta-type="link" data-cta-destination="self" data-cta-location="HomePage" href="/courses/all">Catalog</a>
#       </li>
#       <li>
#         <a id="ga-bbb18c" title="For Business" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Business - For Business" data-cta-message="For Business" data-cta-type="link" data-cta-destination="self" data-cta-location="HomePage" href="/business">For Business</a>
#       </li>
#       <li class="student" data-show-student>
#         <a id="ga-e75854" title="Blog" target="_blank" class="white" data-show-student="" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Blog - Blog" data-cta-message="Blog" data-cta-type="link" data-cta-destination="new_window" data-cta-location="HomePage" href="https://blog.udacity.com">Blog</a>
#       </li>
#       <li class="student" data-show-student>
#         <a id="ga-4bbc1a" title="My Classroom" data-show-student="" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Classroom - My Classroom" data-cta-message="My Classroom" data-cta-type="button" data-cta-destination="self" data-cta-location="HomePage" href="https://classroom.udacity.com/">My Classroom</a>
#       </li>
#       <li class="guest" data-show-guest>
#        <a id="ga-3fc90d" title="Sign In" data-show-guest="" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Classroom - Sign In" data-cta-message="Sign In" data-cta-type="button" data-cta-destination="self" data-cta-location="HomePage" href="https://auth.udacity.com/sign-in?next=https%3A%2F%2Fclassroom.udacity.com%2Fauthenticated">Sign In</a>
#       </li>
#       <li class="guest" data-show-guest>
#         <a id="ga-2490cf" title="Get Started" class="turquoise" data-show-guest="" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Sign Up - Get Started" data-cta-message="Get Started" data-cta-type="link" data-cta-destination="self" data-cta-location="HomePage" href="https://auth.udacity.com/sign-up?next=https%3A%2F%2Fclassroom.udacity.com%2Fauthenticated">Get Started</a>
#       </li>
#     </ul>
#   </nav>
# </header>
#   <div id="contain-all">
#     <div class="banner featured" data-eyebrow>
#   <p>
#       <span class="brow"><span data-content-block="header/eyebrow">Get the edge over other job applicants. <a href="http://blog.udacity.com/2017/07/inside-the-mind-of-a-recruiter.html">Learn directly</a> from Udacity's Head of Recruiting!</span></span>
#   </p>
# </div>
#
#
# <header class="header">
#   <div class="header__navbar">
#     <div class="header__navbar--toggle">
#       <a href="#" class="nav-toggle">
#         <span class="bar bar_top"></span>
#         <span class="bar bar_mid"></span>
#         <span class="bar bar_bottom"></span>
#       </a>
#     </div>
#     <div class="header__navbar--logo">
#       <a id="ga-6107d9" title="Udacity" class="logo-link" href="/">
#         <div class="logo-wordmark">
#           <svg xmlns="http://www.w3.org/2000/svg" width="180" height="30" viewbox="0 0 180 30" alt="Udacity">
#   <g fill="none" fill-rule="evenodd">
#     <path id="wordmark" fill="#2E3D49" d="M57.6 17.239187c0 2.546698-2.085517 4.407747-4.965517 4.407747-2.88 0-4.965517-1.86105-4.965517-4.407747V7.835994H45.68276v9.501143c0 3.330298 2.88 6.170846 6.951723 6.170846 4.071724 0 6.951724-2.938498 6.951724-6.170846V7.835994H57.6v9.403193zm16.286897-9.403193h-5.36276v15.67199h5.36276c4.468965 0 7.547586-3.03645 7.547586-7.835996 0-4.701596-3.07862-7.835994-7.547586-7.835994zm-.19862 13.71299h-3.177932V9.794994h3.17793c3.376553 0 5.76 2.252847 5.76 5.876994 0 3.917998-2.482757 5.779046-5.76 5.876996zm43.49793.29385c-3.575172 0-5.95862-2.644648-5.95862-6.170846 0-3.526197 2.482758-6.072895 5.95862-6.072895 2.78069 0 4.468966 1.5672 4.468966 1.5672l.794483-1.3713s-1.787587-1.86105-5.46207-1.86105c-4.766896 0-7.746206 3.526198-7.746206 7.738045 0 4.309797 3.07862 7.933945 7.944827 7.933945 3.773793 0 5.66069-2.5467 5.66069-2.5467l-1.092414-1.175398c-.09931-.09795-1.588965 1.959-4.568276 1.959zm14.896553-14.00684h1.986206v15.67199h-1.986207zm10.924137 1.959h4.965517v13.71299h1.986207V9.794994h4.96552v-1.959H143.0069m30.587583 0l-4.766896 7.150344-4.866207-7.150347h-2.085518l5.95862 8.717546v6.954445h1.986208v-6.954444l5.85931-8.71754m-81.434482 0l-6.157242 15.67199h1.986207l1.688276-4.5057 6.45517-1.3713 2.18483 5.876998h1.986203l-6.05793-15.67199h-2.085518zm-1.886897 9.305242l2.97931-7.248294h.099315L97.92 16.063788l-5.56138 1.07745z"></path>
#     <path id="mark" fill="#02B3E4" d="M29 .5l1 .5v13c0 5.551887-2.8897 8.695692-5.995216 10.099885L24.0094 24.1l-7.620963 4.388562c-.05877.03456-.11776.068527-.176957.101902l-.08642.049764.001806-.00254C14.48289 29.545895 12.684682 30 11 30 6 30 0 26 0 18V6l2 1v11c0 8 6 10 9 10 1.858706 0 4.86901-.76773 6.89043-3.254517C14.181726 23.872636 10 20.678703 10 14V2.2L2 7 0 6l10-6 1 .5 1 .5v13c0 6.939958 4.515283 8.612086 7.017542 8.933368C19.625786 21.62159 20 19.997902 20 18V5l2 1v12c0 1.852645-.321777 3.49077-.878395 4.91438C23.648223 22.549217 28 20.813144 28 14V2.25L22 6l-2-1 8-5 1 .5z"></path>
#   </g>
# </svg>
#
#         </div>
# </a>      <a id="ga-c105dc" title="Udacity" href="/">
#         <div class="logo-mark">
#           <svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewbox="0 0 30 30" alt="Udacity">
#   <path id="mark" fill="#02B3E4" fill-rule="evenodd" d="M29 .5l1 .5v13c0 5.551887-2.8897 8.695692-5.995216 10.099885L24.0094 24.1l-7.620963 4.388562c-.05877.03456-.11776.068527-.176957.101902l-.08642.049764.001806-.00254C14.48289 29.545895 12.684682 30 11 30 6 30 0 26 0 18V6l2 1v11c0 8 6 10 9 10 1.858706 0 4.86901-.76773 6.89043-3.254517C14.181726 23.872636 10 20.678703 10 14V2.2L2 7 0 6l10-6 1 .5 1 .5v13c0 6.939958 4.515283 8.612086 7.017542 8.933368C19.625786 21.62159 20 19.997902 20 18V5l2 1v12c0 1.852645-.321777 3.49077-.878395 4.91438C23.648223 22.549217 28 20.813144 28 14V2.25L22 6l-2-1 8-5 1 .5z"></path>
# </svg>
#         </div>
# </a>    </div>
#     <div class="header__navbar--navigation">
#       <nav role="navigation">
#         <a id="ga-8a069e" title="Explore" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Pathfinder - Explore" data-analytics-payload="{&quot;cta_message&quot;:&quot;Explore&quot;,&quot;cta_type&quot;:&quot;link&quot;,&quot;cta_destination&quot;:&quot;self&quot;,&quot;cta_location&quot;:&quot;HomePage&quot;}" class="button button--navigation" href="/pathfinder">Explore</a>
#         <a id="ga-3653c3" title="Nanodegree" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Nanodegree - Nanodegree" data-analytics-payload="{&quot;cta_message&quot;:&quot;Nanodegree&quot;,&quot;cta_type&quot;:&quot;link&quot;,&quot;cta_destination&quot;:&quot;self&quot;,&quot;cta_location&quot;:&quot;HomePage&quot;}" class="button button--navigation" href="/nanodegree">Nanodegree</a>
#         <a id="ga-2f132e" title="Catalog" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Catalog - Catalog" data-analytics-payload="{&quot;cta_message&quot;:&quot;Catalog&quot;,&quot;cta_type&quot;:&quot;link&quot;,&quot;cta_destination&quot;:&quot;self&quot;,&quot;cta_location&quot;:&quot;HomePage&quot;}" class="button button--navigation" href="/courses/all">Catalog</a>
#         <a id="ga-773ff8" title="For Business" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Business - For Business" data-analytics-payload="{&quot;cta_message&quot;:&quot;For Business&quot;,&quot;cta_type&quot;:&quot;link&quot;,&quot;cta_destination&quot;:&quot;self&quot;,&quot;cta_location&quot;:&quot;HomePage&quot;}" class="button button--navigation" href="/business">For Business</a>
#         <div class="button button--navigation divider"></div>
#         <a id="ga-66ff47" title="Blog" target="_blank" data-show-student="" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Blog - Blog" data-analytics-payload="{&quot;cta_message&quot;:&quot;Blog&quot;,&quot;cta_type&quot;:&quot;link&quot;,&quot;cta_destination&quot;:&quot;new_window&quot;,&quot;cta_location&quot;:&quot;HomePage&quot;}" class="button button--navigation button--student button--blog" href="http://blog.udacity.com">Blog</a>
#         <a id="ga-9c9acd" title="My Classroom" data-show-student="" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Classroom - My Classroom" data-analytics-payload="{&quot;cta_message&quot;:&quot;My Classroom&quot;,&quot;cta_type&quot;:&quot;button&quot;,&quot;cta_destination&quot;:&quot;self&quot;,&quot;cta_location&quot;:&quot;HomePage&quot;}" class="button button--primary button--student" href="https://classroom.udacity.com/">My Classroom</a>
#         <a id="ga-e634f2" title="Sign In" data-show-guest="" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Classroom - Sign In" data-analytics-payload="{&quot;cta_message&quot;:&quot;Sign In&quot;,&quot;cta_type&quot;:&quot;button&quot;,&quot;cta_destination&quot;:&quot;self&quot;,&quot;cta_location&quot;:&quot;HomePage&quot;}" class="button button--navigation button--student" href="https://auth.udacity.com/sign-in?next=https%3A%2F%2Fclassroom.udacity.com%2Fauthenticated">Sign In</a>
#         <a id="ga-dda148" title="Get Started" data-show-guest="" data-analytics-name="Navbar Link Clicked" data-analytics-category="Navbar Link" data-analytics-label="Navbar Link - Sign Up - Get Started" data-analytics-payload="{&quot;cta_message&quot;:&quot;Get Started&quot;,&quot;cta_type&quot;:&quot;link&quot;,&quot;cta_destination&quot;:&quot;self&quot;,&quot;cta_location&quot;:&quot;HomePage&quot;}" class="button button--turquoise button--guest button--get-started" href="https://auth.udacity.com/sign-up?next=https%3A%2F%2Fclassroom.udacity.com%2Fauthenticated">Get Started</a>
#       </nav>
#     </div>
#   </div>
# </header>
#     <div id="page-content">
#
#
#
#
#
#
#   <div class="container">
#     <div class="row">
#       <div class="col-sm-6">
#         <h1 class="h-slim-top">
#           Courses and Nanodegree Programs
#         </h1>
#       </div>
#
#       <div class="col-sm-6">
#         <div class="row row-gap-small">
#           <div class="col-xs-12">
#             <div class="search">
#               <form id="userSearchForm" class="search_contain" action="#" accept-charset="UTF-8" method="post"><input name="utf8" type="hidden" value="&#x2713;" /><input type="hidden" name="authenticity_token" value="H5+K7uCLFa+CQ67gFrpU5E2khaJk/qYTsgWXJkd4g5EqXtvAH2U0Cwpw2r8l5hT9GZ6Z3SK4VEju1AkKiYBKiA==" />
#                 <input id="userSearchQuery" data-catalog-query type="search" placeholder="Search">
#                 <input id="userSearchSubmit" type="submit">
# </form>            </div>
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <div class="row row-gap-medium">
#       <div class="col-sm-3">
#         <div class="row facet-categories">
#           <div class="col-xs-12">
#             <h4 class="h-slim">Category</h4>
#
#             <!-- all -->
#             <div class="row active">
#               <div class="col-xs-12">
#                 <p class="form-control-static">
#                   <a href="/courses/all" style="display: block; width: 100%">All</a>
#                 </p>
#               </div>
#             </div>
#
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/android" style="display: block; width: 100%;">
#                       Android
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/17" style="display: block; width: 100%;">
#
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/artificial-intelligence" style="display: block; width: 100%;">
#                       Artificial Intelligence
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/data-analytics" style="display: block; width: 100%;">
#                       Data Analytics
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/data-science" style="display: block; width: 100%;">
#                       Data Science
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/deep-learning" style="display: block; width: 100%;">
#                       Deep Learning
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/developer-essentials" style="display: block; width: 100%;">
#                       Developer Essentials
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/digital-marketing" style="display: block; width: 100%;">
#                       Digital Marketing
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/georgia-tech-masters-in-cs" style="display: block; width: 100%;">
#                       Georgia Tech Masters in CS
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/ios" style="display: block; width: 100%;">
#                       iOS
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/machine-learning" style="display: block; width: 100%;">
#                       Machine Learning
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/mobile-app-development" style="display: block; width: 100%;">
#                       Mobile App Development
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/non-tech" style="display: block; width: 100%;">
#                       Non-Tech
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/self-driving-car" style="display: block; width: 100%;">
#                       Self Driving Car
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/software-engineering" style="display: block; width: 100%;">
#                       Software Engineering
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/15" style="display: block; width: 100%;">
#
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/16" style="display: block; width: 100%;">
#
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/virtual-reality" style="display: block; width: 100%;">
#                       Virtual Reality
#                     </a>
#                   </p>
#                 </div>
#               </div>
#               <div class="row ">
#                 <div class="col-xs-12">
#                   <p class="form-control-static">
#                     <!-- Force the clickable region to be the entire width of the container -->
#                     <a href="/courses/web-development" style="display: block; width: 100%;">
#                       Web Development
#                     </a>
#                   </p>
#                 </div>
#               </div>
#           </div>
#         </div>
#
#         <hr>
#
#         <!-- Semantic Type Filters -->
#         <div class="row hidden-xs">
#           <div class="col-xs-12">
#             <h4>Type</h4>
#             <div class="checkbox">
#               <label>
#                 <input data-scope="nanodegrees" type="checkbox" name="Nanodegree" data-filter="nodeType">
#                 <span>Nanodegree Programs</span>
#               </label>
#             </div>
#             <div class="checkbox">
#               <label>
#                 <input data-scope="courses" type="checkbox" name="Free Course" data-filter="nodeType">
#                 <span>Free Courses</span>
#               </label>
#             </div>
#           </div>
#         </div>
#
#         <!-- Skill Level Filters -->
#         <div class="row hidden-xs">
#           <div class="col-xs-12">
#             <h4>Skill level</h4>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="level" type="checkbox"
#                          name="beginner">
#                   <span>Beginner</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="level" type="checkbox"
#                          name="intermediate">
#                   <span>Intermediate</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="level" type="checkbox"
#                          name="advanced">
#                   <span>Advanced</span>
#                 </label>
#               </div>
#           </div>
#         </div>
#
#         <!-- Affiliate Filters -->
#         <div class="row hidden-xs">
#           <div class="col-xs-12">
#             <h4>In Collaboration With</h4>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Alteryx"
#                          name="5448383925583872">
#                   <span>Alteryx</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Affectiva"
#                          name="affectiva">
#                   <span>Affectiva</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Amazon Alexa"
#                          name="amazon-alexa">
#                   <span>Amazon Alexa</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Amazon Appstore for Android"
#                          name="amazon_appstore-for-android">
#                   <span>Amazon Appstore for Android</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Amazon Web Services"
#                          name="amazonwebservices">
#                   <span>Amazon Web Services</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="AT&amp;T"
#                          name="att">
#                   <span>AT&amp;T</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Autodesk"
#                          name="autodesk">
#                   <span>Autodesk</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="BMW"
#                          name="bmw">
#                   <span>BMW</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Bosch"
#                          name="bosch">
#                   <span>Bosch</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Buddybuild"
#                          name="buddybuild">
#                   <span>Buddybuild</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Cloudera"
#                          name="cloudera">
#                   <span>Cloudera</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Didi"
#                          name="didi">
#                   <span>Didi</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Electric Movement"
#                          name="electric-movement">
#                   <span>Electric Movement</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Elektrobit"
#                          name="elektrobit">
#                   <span>Elektrobit</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Facebook"
#                          name="facebook">
#                   <span>Facebook</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Github"
#                          name="github">
#                   <span>Github</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Google"
#                          name="google">
#                   <span>Google</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Google VR"
#                          name="google-vr">
#                   <span>Google VR</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="X"
#                          name="google-x">
#                   <span>X</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Gradle"
#                          name="gradle">
#                   <span>Gradle</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Georgia Institute of Technology"
#                          name="gt">
#                   <span>Georgia Institute of Technology</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Hack Reactor"
#                          name="hackreactor">
#                   <span>Hack Reactor</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Hootsuite"
#                          name="hootsuite">
#                   <span>Hootsuite</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="HubSpot"
#                          name="hubspot">
#                   <span>HubSpot</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="IBM"
#                          name="ibm">
#                   <span>IBM</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="IBM Watson"
#                          name="ibm-watson">
#                   <span>IBM Watson</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="iRobot"
#                          name="i-robot">
#                   <span>iRobot</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="kaggle"
#                          name="kaggle">
#                   <span>kaggle</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Kuka"
#                          name="kuka">
#                   <span>Kuka</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Lockheed Martin"
#                          name="lockheed-martin">
#                   <span>Lockheed Martin</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Lyft"
#                          name="lyft">
#                   <span>Lyft</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="MailChimp"
#                          name="mailchimp">
#                   <span>MailChimp</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="McLaren"
#                          name="mclaren">
#                   <span>McLaren</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Megabots"
#                          name="megabots">
#                   <span>Megabots</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Mercedes"
#                          name="mercedes">
#                   <span>Mercedes</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Mode"
#                          name="mode">
#                   <span>Mode</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="MongoDB"
#                          name="mongodb">
#                   <span>MongoDB</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Moz"
#                          name="moz">
#                   <span>Moz</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="NextEv"
#                          name="nextev">
#                   <span>NextEv</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Nutanix"
#                          name="nutanix">
#                   <span>Nutanix</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Nvidia"
#                          name="nvidia">
#                   <span>Nvidia</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Pramp"
#                          name="pramp">
#                   <span>Pramp</span>
#                 </label>
#               </div>
#               <div class="checkbox">
#                 <label>
#                   <input data-filter="affiliate" type="checkbox"
# ...
#               <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewbox="0 0 24 24" alt="Twitter">
#   <path id="icon-social" fill="#000000" fill-rule="evenodd" d="M8.31918 20.297607c7.58269 0 11.730104-6.270665 11.730104-11.708558 0-.17811 0-.355415-.012056-.531918.806842-.58253 1.50332-1.30381 2.056827-2.13007-.752418.33279-1.550594.551034-2.367883.647446.860623-.51428 1.504742-1.323153 1.812484-2.276086-.809262.47933-1.694616.817138-2.617854.998846-1.277915-1.356348-3.30851-1.68832-4.953145-.809762-1.644634.878557-2.494295 2.74915-2.07254 4.562856-3.3148-.165873-6.403192-1.728667-8.49657-4.29945-1.094224 1.880273-.535316 4.285698 1.276374 5.49325-.656075-.019408-1.29785-.196067-1.871156-.515067v.05215c.000537 1.958854 1.38388 3.646015 3.307482 4.033892-.606946.16522-1.243758.189373-1.861514.0706.540088 1.676313 2.087834 2.824673 3.85163 2.85774-1.459845 1.14521-3.263227 1.766896-5.119965 1.76503-.328013-.00063-.655706-.020453-.981394-.05937 1.885335 1.207662 4.079025 1.84824 6.31918 1.845257"></path>
# </svg>
#
# </a>          </li>
#           <li>
#             <a id="ga-a84695" target="_blank" title="Medium" href="https://medium.com/udacity">
#               <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewbox="0 0 24 24" alt="Medium">
#   <path id="icon-social" fill="#000000" fill-rule="evenodd" d="M21.095868 7.13293c-.003757-.00287-.00662-.006635-.01109-.008786l-.00644-.003228-5.647355-2.830564c-.038283-.019008-.078354-.032098-.118962-.0425-.05098-.013268-.10286-.02116-.155094-.02116-.216277 0-.43166.10885-.548295.29857l-3.251312 5.29639 4.080284 6.64649 5.67544-9.244835c.018965-.030663.00984-.068858-.01717-.090377M9.76754 8.53387v5.96381l5.450657 2.650543m.501547.55504l4.505583 2.21278c.586275.288044 1.06156.08654 1.06156-.45015V8.816878l-5.567143 8.886385zM8.80403 6.973853L3.202026 4.22503c-.1012-.049567-.197495-.073102-.284524-.073102-.24546 0-.41752.186322-.41752.498878V16.52012c0 .31773.236922.693938.526533.836042l4.933935 2.420933c.126637.062048.247096.091467.355928.091467.30669 0 .521627-.232857.521627-.623687V7.02788c0-.022823-.01308-.043863-.033975-.054026"></path>
# </svg>
#
# </a>          </li>
#           <li>
#             <a id="ga-1f56ad" target="_blank" title="LinkedIn" href="https://www.linkedin.com/company/udacity">
#               <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewbox="0 0 24 24" alt="LinkedIn">
#   <path id="icon-social" fill="#000000" fill-rule="evenodd" d="M18.366728 18.338h-2.674412v-4.1775c0-.996-.017032-2.2775-1.389553-2.2775-1.392057 0-1.604447 1.0855-1.604447 2.2065v4.2485h-2.671408v-8.59h2.56371v1.1745h.037068c.356655-.6755 1.229258-1.3875 2.530148-1.3875 2.708475 0 3.208894 1.7785 3.208894 4.092v4.711zM7.011368 8.5745c-.859077 0-1.55185-.6935-1.55185-1.5485 0-.8545.692773-1.548 1.55185-1.548.855572 0 1.549848.6935 1.549848 1.548 0 .855-.694276 1.5485-1.549847 1.5485zM5.67191 18.338h2.67742v-8.59H5.67191v8.59zM19.698675 3H4.329943C3.596095 3 3 3.581 3 4.298v15.403C3 20.418 3.596095 21 4.329943 21h15.368732c.73535 0 1.33395-.582 1.33395-1.299V4.298c0-.717-.5986-1.298-1.33395-1.298z"></path>
# </svg>
#
# </a>          </li>
#           <li>
#             <a id="ga-b4a8c6" target="_blank" title="Instagram" href="https://www.instagram.com/udacity/">
#               <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewbox="0 0 24 24" alt="Instagram">
#   <g id="icon-social" fill="#000000" fill-rule="evenodd">
#     <path d="M12.05987 5.449593c2.152093 0 2.406987.008176 3.25687.04688.78583.0358 1.212596.16686 1.496636.277005.376183.145943.644707.320308.926732.601815.282025.281507.45671.549538.60289.92503.11038.283518.24168.7095.277546 1.493854.038777.848354.046967 1.10278.046967 3.25092 0 2.14814-.00819 2.402565-.04696 3.250886-.03586.784387-.16716 1.210368-.27754 1.493887-.14618.375492-.32086.643522-.60289.92503-.28202.281506-.55055.45587-.92673.601782-.28404.110176-.7108.241237-1.49663.277036-.84975.038706-1.10465.04688-3.25687.04688-2.15222 0-2.40711-.008174-3.25687-.04688-.78583-.0358-1.21259-.16686-1.4966-.277036-.37621-.14591-.644733-.320276-.92676-.601783-.282024-.28151-.45671-.54954-.60289-.92503-.11038-.28352-.24168-.7095-.277545-1.49386-.038775-.84836-.046966-1.10278-.046966-3.25092 0-2.14814.00819-2.40257.046967-3.25089.035868-.78439.16717-1.21037.27755-1.49389.14618-.3755.320865-.64353.60289-.92503.282026-.28151.55055-.45587.926764-.60182.28401-.11015.71077-.24121 1.49657-.27701.849914-.038708 1.10481-.04688 3.2569-.04688m0-1.449597c-2.18895 0-2.46339.00926-3.323064.048412-.85791.03909-1.44378.17507-1.95648.37396-.53001.205594-.97949.480682-1.42756.92793-.448075.44725-.72367.895906-.929645 1.42494-.19926.51176-.33549 1.096553-.37465 1.95289C4.00925 9.586193 4 9.860163 4 12.045093s.009246 2.4589.04847 3.31696c.03916.85634.17539 1.44113.374648 1.95289.205975.529006.48157.97769.929643 1.42494.44808.44725.89756.72234 1.42757.927937.5127.19889 1.09857.33487 1.95649.37396.85968.03915 1.13412.04838 3.32307.04838s2.46343-.00923 3.32307-.04838c.857914-.03909 1.443784-.17507 1.956484-.37396.530008-.2056.97949-.48069 1.42756-.92794s.72367-.89591.929645-1.42494c.19926-.51176.335487-1.09655.37465-1.95289.039225-.85806.048503-1.13203.048503-3.31696 0-2.18493-.009276-2.4589-.0485-3.31696-.03916-.85634-.17539-1.44113-.374646-1.95289-.20598-.52904-.48157-.97769-.929644-1.42494-.44807-.44725-.897554-.72234-1.42756-.92794-.5127-.19889-1.09857-.33487-1.956485-.37396C14.523295 4.00926 14.24882 4 12.05987 4"></path>
#     <path d="M12.06243 7.916348c-2.285827 0-4.138874 1.849643-4.138874 4.13127 0 2.28163 1.853047 4.131272 4.138874 4.131272 2.285826 0 4.138873-1.849643 4.138873-4.13127 0-2.28163-1.853047-4.131272-4.138873-4.131272zm0 6.81298c-1.483775 0-2.686645-1.20066-2.686645-2.68171 0-1.481048 1.20287-2.681708 2.686645-2.681708 1.483775 0 2.686644 1.20066 2.686644 2.68171 0 1.481048-1.20287 2.681708-2.686644 2.681708zm5.269565-6.976198c0 .533185-.433003.965425-.96717.965425-.53417 0-.967205-.43224-.967205-.965426 0-.53319.433036-.9654.967204-.9654s.96717.43221.96717.96539"></path>
#   </g>
# </svg>
#
# </a>          </li>
#           <li>
#             <a id="ga-a99657" target="_blank" title="Google +" href="https://plus.google.com/+Udacity/posts">
#               <svg xmlns="http://www.w3.org/2000/svg" width="31" height="24" viewbox="0 0 31 24" alt="Google +">
#   <path id="icon-social" fill="#000000" fill-rule="evenodd" d="M25.590768 10.61339V7.82461h-1.99565v2.78878H20.72138v1.991985h2.873737v2.868458h1.99565v-2.868458h2.793912V10.61339h-2.793913zm-14.528338-.15936v3.187177s3.09757-.004143 4.35882-.004143c-.68299 2.066166-1.744997 3.19132-4.35882 3.19132-2.645196 0-4.709737-2.14043-4.709737-4.780765 0-2.640338 2.06454-4.780766 4.709737-4.780766 1.398552 0 2.301783.490666 3.130298 1.174554.66314-.661977.607795-.756318 2.295078-2.346798C15.055488 4.793288 13.151796 4 11.06243 4 6.609653 4 3 7.603023 3 12.04762c0 4.444516 3.609653 8.047618 8.06243 8.047618 6.655655 0 8.28243-5.784724 7.743125-9.641207H11.06243z"></path>
# </svg>
#
# </a>          </li>
#         </ul>
#       </div>
#     </section>
#     <section class="text-center">
#       <p class="micro mb-half">"Nanodegree" is a registered trademark of Udacity. <span>&copy; 2011&ndash;2017 Udacity, Inc.</span></p>
#       <p class="micro legible center mb-0">Udacity is not an accredited university and we don't confer degrees.</p>
#     </section>
#   </div>
# </footer>
#
#   <script type="text/javascript">
#     if (!window.jQuery) {
#       var s = document.createElement('script');
#       s.src = '/public/vendor/jquery-1.12.2.min.js';
#       document.body.append(s);
#     }
#   </script>
#   <script src="https://d125fmws0bore1.cloudfront.net/assets/legacy/legacy-e73611603c02506e79c9dc4d021cb4c05ccf65eaeb615627156a458f5ac2c2da.js"></script>
#     <div id="pathModal" class="path-modal modal-content mfp-hide col-xs-10 col-xs-offset-1 col-sm-8 col-sm-offset-2 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2">
#     <h2 class="path-modal__header">Choose Your Path</h2>
#     <p class="path-modal__subhead">Select one of the paths below to start exploring learning options</p>
#       <div class="path-modal__card-container">
#         <input type="radio" id="pathModalND" name="path" value="Nanodegree">
#         <label class="path-modal__card" for="pathModalND">
#           <svg xmlns="http://www.w3.org/2000/svg" width="67" height="40" viewbox="0 0 67 40" role="presentation">
#   <g fill="none" fill-rule="evenodd">
#     <rect width="67" height="40" fill="#FAFBFC" opacity="0"></rect>
#     <path fill="#02B3E4" d="M56.9184202,29.578489 C56.7944323,29.8330061 56.5470765,29.9909132 56.2774029,29.9909132 L35.192024,29.9909132 C34.956447,29.9909132 34.7363685,29.8696512 34.6006018,29.6651048 L33.5002093,28.0040814 L32.399197,29.6651048 C32.2634302,29.8696512 32.0433518,29.9909132 31.8077748,29.9909132 L10.7223959,29.9909132 C10.4527223,29.9909132 10.2059864,29.8330061 10.0813785,29.578489 C9.95739068,29.3253046 9.97598886,29.0188181 10.1309737,28.7856219 L22.3654778,10.3258084 C22.3791164,10.3051539 22.3970947,10.2891633 22.4125932,10.2705076 C22.424992,10.254517 22.4373907,10.2391927 22.4516493,10.2245347 C22.4826463,10.1912209 22.516743,10.1632374 22.5526995,10.1372526 C22.568198,10.125926 22.5824566,10.113933 22.5991949,10.1039389 C22.638871,10.0792867 22.6816469,10.0612973 22.7250426,10.0453067 C22.7405411,10.0399765 22.7547997,10.0319812 22.7702982,10.0273173 C22.8304323,10.0099941 22.8930462,10 22.9569,10 L22.9581398,10 L44.0416589,10 L44.0435187,10 C44.1073725,10 44.1693664,10.0099941 44.2295006,10.0273173 C44.244999,10.0319812 44.2592576,10.0399765 44.2747561,10.0453067 C44.3181519,10.0612973 44.3609277,10.0792867 44.4006038,10.1032726 C44.4173422,10.113933 44.4322207,10.125926 44.4477192,10.1372526 C44.4836757,10.1632374 44.5171524,10.1912209 44.5487693,10.2238684 C44.562408,10.2391927 44.5748068,10.254517 44.5878255,10.2705076 C44.603324,10.2891633 44.6213023,10.3051539 44.6349409,10.3258084 L56.8688251,28.7856219 C57.0244298,29.0188181 57.0424081,29.3253046 56.9184202,29.578489 L56.9184202,29.578489 L56.9184202,29.578489 Z M30.915682,27.9041401 L32.1877976,26.0239122 L23.3951971,12.7570457 L13.145739,27.9041401 L30.915682,27.9041401 L30.915682,27.9041401 L30.915682,27.9041401 Z M25.381483,12.0867731 L33.5002093,24.0843859 L41.6183158,12.0867731 L25.381483,12.0867731 L25.381483,12.0867731 L25.381483,12.0867731 Z M43.6046016,12.757712 L34.8120011,26.0239122 L36.0841168,27.9041401 L53.8540597,27.9041401 L43.6046016,12.757712 L43.6046016,12.757712 L43.6046016,12.757712 Z"></path>
#   </g>
# </svg>
#
#           <h3>Nanodegree Programs</h3>
#           <p>Best-in-class courses taught by expert instructors</p>
#           <p>Mentoring, project review, and career guidance</p>
#           <p>Certification built and recognized by industry leaders like Google, Facebook, Apple, and more</p>
#         </label>
#         <div class="spacer"></div>
#         <input type="radio" id="pathModalFC" name="path" value="Free Course">
#         <label class="path-modal__card" for="pathModalFC">
#           <svg xmlns="http://www.w3.org/2000/svg" width="67" height="40" viewbox="0 0 67 40" role="presentation">
#   <g fill="#15C26B" fill-rule="evenodd" transform="translate(8 6)">
#     <path d="M28.7631583 17.3684214C28.3684215 17.3684214 27.9736846 17.1315793 27.7368425 16.8157898L19.052632 2.60526347C18.8157899 2.21052663 18.8157899 1.81578979 19.052632 1.42105295 19.2894741 1.02631611 19.6842109.789474 20.0789478.789474L37.4473688.789474C37.8421057.789474 38.2368425 1.02631611 38.4736846 1.42105295 38.7105267 1.81578979 38.7105267 2.289474 38.4736846 2.60526347L29.7894741 16.8157898C29.552632 17.1315793 29.1578951 17.3684214 28.7631583 17.3684214L28.7631583 17.3684214 28.7631583 17.3684214 28.7631583 17.3684214zM22.2105267 3.15789505L28.7631583 13.8947372 35.3157899 3.15789505 22.2105267 3.15789505 22.2105267 3.15789505 22.2105267 3.15789505 22.2105267 3.15789505zM25.6052636 28.4210529L1.92105304 28.4210529C1.5263162 28.4210529 1.13157935 28.1842108.894737249 27.789474.657895143 27.3947372.657895143 27.0000003.894737249 26.6052635L12.7368425 6.07894768C12.9736846 5.68421084 13.3684215 5.44736874 13.7631583 5.44736874 14.1578951 5.44736874 14.552632 5.68421084 14.7894741 6.07894768L26.6315794 26.6052635C26.8684215 27.0000003 26.8684215 27.3947372 26.6315794 27.789474 26.3947372 28.1842108 26.0000004 28.4210529 25.6052636 28.4210529L25.6052636 28.4210529 25.6052636 28.4210529 25.6052636 28.4210529zM3.97368462 26.0526319L23.552632 26.0526319 13.7631583 9.07894768 3.97368462 26.0526319 3.97368462 26.0526319 3.97368462 26.0526319 3.97368462 26.0526319zM50.0789478 28.4210529L32.7105267 28.4210529C32.3157899 28.4210529 31.921053 28.1842108 31.6842109 27.789474 31.4473688 27.3947372 31.4473688 26.9210529 31.6842109 26.6052635L40.3684215 12.3947372C40.6052636 12.0789477 41.0000004 11.8421056 41.3947372 11.8421056 41.7894741 11.8421056 42.1842109 12.0789477 42.421053 12.3947372L51.1052636 26.6052635C51.3421057 27.0000003 51.3421057 27.3947372 51.1052636 27.789474 50.8684215 28.1842108 50.4736846 28.4210529 50.0789478 28.4210529L50.0789478 28.4210529 50.0789478 28.4210529 50.0789478 28.4210529zM34.8421057 26.0526319L48.0263162 26.0526319 41.3947372 15.3157898 34.8421057 26.0526319 34.8421057 26.0526319 34.8421057 26.0526319 34.8421057 26.0526319z"></path>
#   </g>
# </svg>
#
#           <h3>Free Courses</h3>
#           <p>Best-in-class courses taught by expert instructors</p>
#           <p>Craft your own independent study path</p>
#           <p>Learn the skills to achieve your individual goals</p>
#         </label>
#       </div>
#     <button id="pathModalSubmit" class="path-modal__submit btn btn-primary" disabled>Start Exploring</button>
#   </div>
#
#   <div id="bookmarks-catalog-modal" class="bookmarks-catalog-modal modal-content mfp-hide mfp-prevent-close col-xs-12 col-sm-8 col-sm-offset-2 col-md-6 col-md-offset-3 col-lg-4 col-lg-offset-4">
#     <h2 class="bookmarks-catalog-modal--header">Save Your Bookmarks</h2>
#     <div class="row">
#       <ul id="bookmarks-catalog-modal--content" class="bookmarks-catalog-modal--content col-sm-10 col-sm-offset-1"></ul>
#     </div>
#     <p class="bookmarks-catalog-modal--subhead">Create an account to keep your bookmarks.</p>
#     <div class="button-wrapper text-center">
#       <div class="row">
#         <div class="col-sm-10 col-sm-offset-1">
#           <a id="ga-c6a147" class="btn btn-primary bookmarks-catalog-modal--cta" data-analytics-name="CTA Clicked" data-analytics-category="Bookmarks Catalog Modal CTA - Sign Up" data-analytics-label="Sign Up" data-analytics-type="CTA" data-analytics-payload="{&quot;cta_message&quot;:&quot;Sign Up&quot;,&quot;cta_type&quot;:&quot;button&quot;,&quot;cta_destination&quot;:&quot;auth&quot;,&quot;cta_location&quot;:&quot;Catalog&quot;}" href="https://auth.udacity.com/sign-up?next=https://www.udacity.com/courses/all?bookmarks=link">Sign Up</a>
#
#           <div class="row row-gap-small text-subdued">
#             <p>
#               Already have an account?
#               <a id="ga-f23764" href="https://auth.udacity.com/sign-up?next=https://www.udacity.com/courses/all?bookmarks=link">Sign in</a>.
#             </p>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div class="row row-gap-medium"></div>
#   </div>
#
#   <script src="https://d125fmws0bore1.cloudfront.net/assets/legacy/standalone/udacity/catalog-c02adb6ffe5b8039ae91835aa63ae5006abf878fe2e7fd4b4bdc12507e3d64c1.js"></script>
#   <script src="https://d125fmws0bore1.cloudfront.net/assets/standalone/udacity/bookmarks-b1d4f246938f95e7b0ee78c602b4acfa923a843ca7eb7a6560a1a51ea6d375cc.js"></script>
#   <script src="https://d125fmws0bore1.cloudfront.net/assets/external/typeahead-f51cf060cd88559a2d30f8a162be93b9916f520bb95440670f10668237b00fe9.js"></script>
#   <script src="https://d125fmws0bore1.cloudfront.net/assets/external/bloodhound-f284cd9d1b03a31dbf4e8cda6dc8eccb8b980c7f43b92932c5260b8997cb3f18.js"></script>
#
# </body>
# </html>

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
#
#
#
#   All Courses and Nanodegree Programs | Udacity
#
#
#
#
#
#
#
#
#
#
# window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"2059d2614a","applicationID":"12625862","transactionName":"dwpcEUoOXlUHSkxMF1UGWRYXElpWFQ==","queueTime":0,"applicationTime":166,"agent":""}
# (window.NREUM||(NREUM={})).loader_config={xpid:"XQAAV1JWGwICUlNXDwcF"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"],"-")},{}],7:[function(t,n,e){var r=t("ee").get("raf"),o=t(18)(r),i="equestAnimationFrame";n.exports=r,o.inPlace(window,["r"+i,"mozR"+i,"webkitR"+i,"msR"+i],"raf-"),r.on("raf-start",function(t){t[0]=o(t[0],"fn-")})},{}],8:[function(t,n,e){function r(t,n,e){t[0]=a(t[0],"fn-",null,e)}function o(t,n,e){this.method=e,this.timerDuration=isNaN(t[1])?0:+t[1],t[0]=a(t[0],"fn-",this,e)}var i=t("ee").get("timer"),a=t(18)(i),s="setTimeout",c="setInterval",f="clearTimeout",u="-start",d="-";n.exports=i,a.inPlace(window,[s,"setImmediate"],s+d),a.inPlace(window,[c],c+d),a.inPlace(window,[f,"clearImmediate"],f+d),i.on(c+u,r),i.on(s+u,o)},{}],9:[function(t,n,e){function r(t,n){d.inPlace(n,["onreadystatechange"],"fn-",s)}function o(){var t=this,n=u.context(t);t.readyState>3&&!n.resolved&&(n.resolved=!0,u.emit("xhr-resolved",[],t)),d.inPlace(t,y,"fn-",s)}function i(t){g.push(t),h&&(x?x.then(a):w?w(a):(E=-E,O.data=E))}function a(){for(var t=0;t34||p
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","page","once","off","on"];analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);analytics.push(e);return analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t){var e=document.createElement("script");e.type="text/javascript";e.async=!0;e.src=("https:"===document.location.protocol?"https://":"http://")+"cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(e,n)};analytics.SNIPPET_VERSION="3.1.0";
#       analytics.load('oP3ZXzj7KM9lvyAXexoorjH0YbvawAKg');
#       analytics.page(
#         "Catalog",
#         "Catalog - All",
#         {},
#         {}
#       );
#   }}();
#
#
#
#   analytics.ready(function(){
#     ga('create', 'UA-28524234-29', 'auto', {'name': 'optimizeTracker'});
#     ga('optimizeTracker.require', 'GTM-MDRX326');
#     ga('optimizeTracker.send', 'pageview');
#   });
#   analytics.on('track', function(event, properties, options){
#   // custom logic based on event properties
#     ga('optimizeTracker.send', {
#         hitType: 'event',
#         eventCategory: properties.category || 'All',
#         eventAction: event,
#         eventLabel: properties.label || 'All',
#         nonInteraction: true
#     })
#   });
#
#
#
#
#
#   if (!window.jQuery) {
#     var s = document.createElement('script');
#     s.src = '/public/vendor/jquery-1.12.2.min.js';
#     document.body.append(s);
#   }
#
#
#
#
#
#
#
#     {}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Explore
#
#
#         Nanodegree
#
#
#         Catalog
#
#
#         For Business
#
#
#         Blog
#
#
#         My Classroom
#
#
#        Sign In
#
#
#         Get Started
#
#
#
#
#
#
#
#       Get the edge over other job applicants. Learn directly from Udacity's Head of Recruiting!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Explore
#         Nanodegree
#         Catalog
#         For Business
#
#         Blog
#         My Classroom
#         Sign In
#         Get Started
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Courses and Nanodegree Programs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Category
#
#
#
#
#
#                   All
#
#
#
#
#
#
#
#
#
#                       Android
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                       Artificial Intelligence
#
#
#
#
#
#
#
#
#
#                       Data Analytics
#
#
#
#
#
#
#
#
#
#                       Data Science
#
#
#
#
#
#
#
#
#
#                       Deep Learning
#
#
#
#
#
#
#
#
#
#                       Developer Essentials
#
#
#
#
#
#
#
#
#
#                       Digital Marketing
#
#
#
#
#
#
#
#
#
#                       Georgia Tech Masters in CS
#
#
#
#
#
#
#
#
#
#                       iOS
#
#
#
#
#
#
#
#
#
#                       Machine Learning
#
#
#
#
#
#
#
#
#
#                       Mobile App Development
#
#
#
#
#
#
#
#
#
#                       Non-Tech
#
#
#
#
#
#
#
#
#
#                       Self Driving Car
#
#
#
#
#
#
#
#
#
#                       Software Engineering
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                       Virtual Reality
#
#
#
#
#
#
#
#
#
#                       Web Development
#
#
#
#
#
#
#
#
#
#
#
#
#             Type
#
#
#
#                 Nanodegree Programs
#
#
#
#
#
#                 Free Courses
#
#
#
#
#
#
#
#
#             Skill level
#
#
#                   <input data-filter="level" type="checkbox"
#                          name="beginner">
#                   Beginner
#
#
#
#
#                   <input data-filter="level" type="checkbox"
#                          name="intermediate">
#                   Intermediate
#
#
#
#
#                   <input data-filter="level" type="checkbox"
#                          name="advanced">
#                   Advanced
#
#
#
#
#
#
#
#
#             In Collaboration With
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Alteryx"
#                          name="5448383925583872">
#                   Alteryx
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Affectiva"
#                          name="affectiva">
#                   Affectiva
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Amazon Alexa"
#                          name="amazon-alexa">
#                   Amazon Alexa
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Amazon Appstore for Android"
#                          name="amazon_appstore-for-android">
#                   Amazon Appstore for Android
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Amazon Web Services"
#                          name="amazonwebservices">
#                   Amazon Web Services
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="AT&amp;T"
#                          name="att">
#                   AT&amp;T
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Autodesk"
#                          name="autodesk">
#                   Autodesk
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="BMW"
#                          name="bmw">
#                   BMW
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Bosch"
#                          name="bosch">
#                   Bosch
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Buddybuild"
#                          name="buddybuild">
#                   Buddybuild
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Cloudera"
#                          name="cloudera">
#                   Cloudera
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Didi"
#                          name="didi">
#                   Didi
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Electric Movement"
#                          name="electric-movement">
#                   Electric Movement
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Elektrobit"
#                          name="elektrobit">
#                   Elektrobit
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Facebook"
#                          name="facebook">
#                   Facebook
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Github"
#                          name="github">
#                   Github
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Google"
#                          name="google">
#                   Google
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Google VR"
#                          name="google-vr">
#                   Google VR
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="X"
#                          name="google-x">
#                   X
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Gradle"
#                          name="gradle">
#                   Gradle
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Georgia Institute of Technology"
#                          name="gt">
#                   Georgia Institute of Technology
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Hack Reactor"
#                          name="hackreactor">
#                   Hack Reactor
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Hootsuite"
#                          name="hootsuite">
#                   Hootsuite
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="HubSpot"
#                          name="hubspot">
#                   HubSpot
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="IBM"
#                          name="ibm">
#                   IBM
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="IBM Watson"
#                          name="ibm-watson">
#                   IBM Watson
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="iRobot"
#                          name="i-robot">
#                   iRobot
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="kaggle"
#                          name="kaggle">
#                   kaggle
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Kuka"
#                          name="kuka">
#                   Kuka
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Lockheed Martin"
#                          name="lockheed-martin">
#                   Lockheed Martin
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Lyft"
#                          name="lyft">
#                   Lyft
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="MailChimp"
#                          name="mailchimp">
#                   MailChimp
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="McLaren"
#                          name="mclaren">
#                   McLaren
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Megabots"
#                          name="megabots">
#                   Megabots
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Mercedes"
#                          name="mercedes">
#                   Mercedes
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Mode"
#                          name="mode">
#                   Mode
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="MongoDB"
#                          name="mongodb">
#                   MongoDB
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Moz"
#                          name="moz">
#                   Moz
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="NextEv"
#                          name="nextev">
#                   NextEv
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Nutanix"
#                          name="nutanix">
#                   Nutanix
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Nvidia"
#                          name="nvidia">
#                   Nvidia
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Pramp"
#                          name="pramp">
#                   Pramp
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Salesforce"
#                          name="salesforce">
#                   Salesforce
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Samsung"
#                          name="samsung">
#                   Samsung
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="San Jose State University"
#                          name="sjsu">
#                   San Jose State University
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Tableau"
#                          name="tableau">
#                   Tableau
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="23andMe"
#                          name="twentythree">
#                   23andMe
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Twitter"
#                          name="twitter">
#                   Twitter
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Uber ATG"
#                          name="uber-atg">
#                   Uber ATG
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Unity"
#                          name="Unity">
#                   Unity
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Upload Collective"
#                          name="Upload">
#                   Upload Collective
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Venmo"
#                          name="venmo">
#                   Venmo
#
#
#
#
#                   <input data-filter="affiliate" type="checkbox"
#                          data-display-name="Vive"
#                          name="vive">
#                   Vive
#
#
#
#
#
#
#
#
#             Technology
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="account-kit">
#                   account kit
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="ajax">
#                   ajax
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="algorithmic-trading">
#                   algorithmic trading
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="analytics">
#                   analytics
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="android">
#                   android
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="apis">
#                   apis
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="app">
#                   app
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="apps">
#                   apps
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="asynchronous-javascript">
#                   asynchronous javascript
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="asynchronous-requests">
#                   asynchronous requests
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="async-requests">
#                   async requests
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="bash">
#                   bash
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="beginner">
#                   beginner
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="big-data">
#                   big data
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="client">
#                   client
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="cloud">
#                   cloud
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="collaboration">
#                   collaboration
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="command-line-vcs">
#                   command line vcs
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="communication">
#                   communication
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="controller">
#                   controller
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="css">
#                   css
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="d3">
#                   d3
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="data">
#                   data
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="deployment">
#                   deployment
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="design-pattern">
#                   design pattern
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="development">
#                   development
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="ecmascript">
#                   ecmascript
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="es6">
#                   es6
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="facebook-for-developers">
#                   facebook for developers
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="fetch">
#                   fetch
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="finance">
#                   finance
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="firebase">
#                   firebase
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="fire-base">
#                   fire base
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="fork">
#                   fork
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="fundamentals">
#                   fundamentals
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="git">
#                   git
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="gradle">
#                   gradle
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="hadoop">
#                   hadoop
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="hdfs">
#                   hdfs
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="heroku">
#                   heroku
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="html">
#                   html
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="http">
#                   http
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="https">
#                   https
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="investment">
#                   investment
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="ios">
#                   ios
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="java">
#                   java
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="javascript">
#                   javascript
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="jquery">
#                   jquery
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="linux">
#                   linux
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="machine-learning">
#                   machine learning
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="mapreduce">
#                   mapreduce
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="mobile">
#                   mobile
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="model">
#                   model
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="mvc">
#                   mvc
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="objective-c">
#                   objective-c
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="passwordless-login">
#                   passwordless login
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="programming">
#                   programming
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="pull-request">
#                   pull request
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="python">
#                   python
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="r">
#                   r
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="rebase">
#                   rebase
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="ruby">
#                   ruby
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="server">
#                   server
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="servers">
#                   servers
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="shell">
#                   shell
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="sinatra">
#                   sinatra
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="sql">
#                   sql
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="squashing">
#                   squashing
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="swift">
#                   swift
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="unity">
#                   unity
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="unreal">
#                   unreal
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="version-control">
#                   version control
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="version-control-system">
#                   version control system
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="view">
#                   view
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="virtual-reality">
#                   virtual reality
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="vr">
#                   vr
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="web-application">
#                   web application
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="web-development">
#                   web development
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="xhr">
#                   xhr
#
#
#
#
#                   <input data-filter="technology" type="checkbox"
#                          name="xml">
#                   xml
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     All Courses and Nanodegree Programs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="nd100"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd100"] = {
#           "affiliate_ids": ["tableau","mode"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Data Foundations Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Data Foundations Nanodegree
#
#
#               New
#
#
#
#             4 Projects
#
#
#
#
#
#             Beginner
#
#
#
#
#
#         Master data fundamentals applicable to any industry, and learn to make data-driven decisions. Learn Excel and SQL, and gain data visualization skills with Tableau.
#
#
#
#
#
#
#
#
#
#   192
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Tableau, Mode
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="nd002"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd002"] = {
#           "affiliate_ids": ["kaggle","tableau","mode"],
#           "technology_ids": ["hadoop","python","r","d3"],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Data Analyst Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Data Analyst Nanodegree
#
#
#               New
#
#
#
#             22 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         Prepare for a data science career. Learn to use Python, R, SQL, and Tableau to uncover insights, communicate critical findings, and create data-driven solutions.
#
#
#
#
#
#
#
#
#
#   2.98K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               kaggle, Tableau, Mode
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="nd019"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd019"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "React Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               React Nanodegree
#
#
#               New
#
#
#
#             3 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         React is completely transforming Front-End Development. Master this powerful UI library from Facebook with Udacity and the experts from React Training.
#
#
#
#
#
#
#
#
#
#   550
#
#
#
#
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="nd000"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd000"] = {
#           "affiliate_ids": [],
#           "technology_ids": ["javascript","css","html","python"],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Intro to Programming Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Intro to Programming Nanodegree
#
#
#               New
#
#
#
#             5 Projects
#
#
#
#
#
#             Beginner
#
#
#
#
#
#         Udacity&#39;s Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.
#
#
#
#
#
#
#
#
#
#   2.48K
#
#
#
#
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="nd017"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd017"] = {
#           "affiliate_ids": ["google-vr","vive","Upload","Unity","samsung"],
#           "technology_ids": ["unity","vr","virtual-reality","unreal"],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "VR Developer Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               VR Developer Nanodegree
#
#
#               New
#
#
#
#             13 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
# ...
#         window.nodeHash["cx31"] = {
#           "affiliate_ids": ["nvidia","uber-atg"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Deep Learning"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Deep Learning
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Build and train deep neural networks to classify traffic signs and to drive a car in a simulator.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Nvidia, Uber ATG
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="cx32"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx32"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Computer Vision"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Computer Vision
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Construct computer vision pipelines for lane detection and vehicle tracking.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="cx33"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx33"] = {
#           "affiliate_ids": ["mercedes"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Sensor Fusion"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Sensor Fusion
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Fuse lidar and radar sensor data to track objects over time.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Mercedes
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="cx34"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx34"] = {
#           "affiliate_ids": ["mercedes"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Localization"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Localization
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Pinpoint where your vehicle is with single-digit centimeter level accuracy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Mercedes
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="cx35"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx35"] = {
#           "affiliate_ids": ["uber-atg"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Control"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Control
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Actuate the vehicle using control algorithms of varying levels of complexity.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Uber ATG
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="cx36"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx36"] = {
#           "affiliate_ids": ["mercedes"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Path Planning"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Path Planning
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Path planning for self-driving cars involves three phases: environmental prediction, behavioral planning, and trajectory generation.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Mercedes
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="cx37"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx37"] = {
#           "affiliate_ids": ["nvidia"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Advanced Deep Learning"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Advanced Deep Learning
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Identify free space on the road so that your vehicle can plan the optimal path.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Nvidia
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="cx38"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx38"] = {
#           "affiliate_ids": ["elektrobit"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Functional Safety"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Functional Safety
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Ensuring acceptable risk levels in accordance with ISO 26262 requires analysis of entire systems.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Elektrobit
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="cx39"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx39"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - System Integration"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - System Integration
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Pull together everything you&#39;ve learned to operate a real self-driving car.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <div data-course-summary
#        id="ud210"
#        data-filter-state="show"
#        class="course-summary-card row row-gap-medium">
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["ud210"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Free Course"],
#           "title": "C++ For Programmers"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               C++ For Programmers
#
#
#               New
#
#
#
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         This course teaches C++ to students already familiar with a programming language.
# Students will learn how to use header files, control flow, functions, classes.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               No Matching Courses
#
#
#               Courses matching these results can only be found in an alternate dimension.
#
#               Please modify your search.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Featured Programs
#
#                   Android Basics
#                   Android Developer
#                   Become an iOS Developer
#                   Business Analyst
#                   Data Analyst
#                   Data Foundations
#                   Front-End Web Developer
#                   Full Stack Web Developer
#                   Intro to Programming
#                   React
#
#
#
#             Only At Udacity
#
#                   Artificial Intelligence
#                   Deep Learning Foundations
#                   Digital Marketing
#                   Machine Learning Engineer
#                   Robotics
#                   Self-Driving Car Engineer
#                   VR Developer
#
#
#
#           Resources
#
#             Catalog
#             Career Resource Center
#             Hiring Partners
#             Student Success
#             Udacity Connect
#             Udacity Talks
#             Scholarships
#
#           Programs
#
#             Nanodegree Plus
#             Veterans
#             Georgia Tech
#             Udacity Self-Driving Car
#
#
#
#           Company
#
#             About
#             Blog
#             In the News
#             Jobs
#             Mobile
#             Udacity Intersect
#
#           Business
#
#             Udacity for Business
#             Corporate Training
#             Hire Graduates
#
#
#
#           Support
#
#             Contact Us
#             Help and FAQ
#             Service Status
#             Course Guides
#             Tech Requirements
#             Legal &amp; Privacy
#             Regulatory Information
#             Site Map
#
#
#
#
#
#
#
#           &copy; 2011&ndash;2017 Udacity, Inc.
#           Legal &amp; Privacy
#           Regulatory Information
#           Site Map
#
#
#
#
#
#             Brazil
#             China
#             Germany
#             India
#             United States
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       "Nanodegree" is a registered trademark of Udacity. &copy; 2011&ndash;2017 Udacity, Inc.
#       Udacity is not an accredited university and we don't confer degrees.
#
#
#
#
#
#     if (!window.jQuery) {
#       var s = document.createElement('script');
#       s.src = '/public/vendor/jquery-1.12.2.min.js';
#       document.body.append(s);
#     }
#
#
#
#     Choose Your Path
#     Select one of the paths below to start exploring learning options
#
#
#
#
#
#
#
#
#
#
#           Nanodegree Programs
#           Best-in-class courses taught by expert instructors
#           Mentoring, project review, and career guidance
#           Certification built and recognized by industry leaders like Google, Facebook, Apple, and more
#
#
#
#
#
#
#
#
#
#
#           Free Courses
#           Best-in-class courses taught by expert instructors
#           Craft your own independent study path
#           Learn the skills to achieve your individual goals
#
#
#     Start Exploring
#
#
#
#     Save Your Bookmarks
#
#
#
#     Create an account to keep your bookmarks.
#
#
#
#           Sign Up
#
#
#
#               Already have an account?
#               Sign in.

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
#
#
#
#   All Courses and Nanodegree Programs | Udacity
#
#
#
#
#
#
#
#
#
#
# window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"2059d2614a","applicationID":"12625862","transactionName":"dwpcEUoOXlUHSkxMF1UGWRYXElpWFQ==","queueTime":0,"applicationTime":166,"agent":""}
# (window.NREUM||(NREUM={})).loader_config={xpid:"XQAAV1JWGwICUlNXDwcF"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,n,e)])}catch(s){try{i("ierr",[s,c.now(),!0])}catch(u){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t){i("err",[t,c.now()])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=window.onerror,u=!1,d=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),u=!0)}s.on("fn-start",function(t,n,e){u&&(d+=1)}),s.on("fn-err",function(t,n,e){u&&(this.thrown=!0,o(e))}),s.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"],"-")},{ ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","page","once","off","on"];analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);analytics.push(e);return analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t){var e=document.createElement("script");e.type="text/javascript";e.async=!0;e.src=("https:"===document.location.protocol?"https://":"http://")+"cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(e,n)};analytics.SNIPPET_VERSION="3.1.0";
#       analytics.load('oP3ZXzj7KM9lvyAXexoorjH0YbvawAKg');
#       analytics.page(
#         "Catalog",
#         "Catalog - All",
#         {},
#         {}
#       );
#   }}();
#
#
#
#   analytics.ready(function(){
#     ga('create', 'UA-28524234-29', 'auto', {'name': 'optimizeTracker'});
#     ga('optimizeTracker.require', 'GTM-MDRX326');
#     ga('optimizeTracker.send', 'pageview');
#   });
#   analytics.on('track', function(event, properties, options){
#   // custom logic based on event properties
#     ga('optimizeTracker.send', {
#         hitType: 'event',
#         eventCategory: properties.category || 'All',
#         eventAction: event,
#         eventLabel: properties.label || 'All',
#         nonInteraction: true
#     })
#   });
#
#
#
#
#
#   if (!window.jQuery) {
#     var s = document.createElement('script');
#     s.src = '/public/vendor/jquery-1.12.2.min.js';
#     document.body.append(s);
#   }
#
#
#
#
#
#
#
#     {}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Explore
#
#
#         Nanodegree
#
#
#         Catalog
#
#
#         For Business
#
#
#         Blog
#
#
#         My Classroom
#
#
#        Sign In
#
#
#         Get Started
#
#
#
#
#
#
#
#       Get the edge over other job applicants. Learn directly from Udacity's Head of Recruiting!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Explore
#         Nanodegree
#         Catalog
#         For Business
#
#         Blog
#         My Classroom
#         Sign In
#         Get Started
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Courses and Nanodegree Programs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Category
#
#
#
#
#
#                   All
#
#
#
#
#
#
#
#
#
#                       Android
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                       Artificial Intelligence
#
#
#
#
#
#
#
#
#
#                       Data Analytics
#
#
#
#
#
#
#
#
#
#                       Data Science
#
#
#
#
#
#
#
#
#
#                       Deep Learning
#
#
#
#
#
#
#
#
#
#                       Developer Essentials
#
#
#
#
#
#
#
#
#
#                       Digital Marketing
#
#
#
#
#
#
#
#
#
#                       Georgia Tech Masters in CS
#
#
#
#
#
#
#
#
#
#                       iOS
#
#
#
#
#
#
#
#
#
#                       Machine Learning
#
#
#
#
#
#
#
#
#
#                       Mobile App Development
#
#
#
#
#
#
#
#
#
#                       Non-Tech
#
#
#
#
#
#
#
#
#
#                       Self Driving Car
#
#
#
#
#
#
#
#
#
#                       Software Engineering
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                       Virtual Reality
#
#
#
#
#
#
#
#
#
#                       Web Development
#
#
#
#
#
#
#
#
#
#
#
#
#             Type
#
#
#
#                 Nanodegree Programs
#
#
#
#
#
#                 Free Courses
#
#
#
#
#
#
#
#
#             Skill level
#
#
#
#                   Beginner
#
#
#
#
#
#                   Intermediate
#
#
#
#
#
#                   Advanced
#
#
#
#
#
#
#
#
#             In Collaboration With
#
#
#
#                   Alteryx
#
#
#
#
#
#                   Affectiva
#
#
#
#
#
#                   Amazon Alexa
#
#
#
#
#
#                   Amazon Appstore for Android
#
#
#
#
#
#                   Amazon Web Services
#
#
#
#
#
#                   AT&T
#
#
#
#
#
#                   Autodesk
#
#
#
#
#
#                   BMW
#
#
#
#
#
#                   Bosch
#
#
#
#
#
#                   Buddybuild
#
#
#
#
#
#                   Cloudera
#
#
#
#
#
#                   Didi
#
#
#
#
#
#                   Electric Movement
#
#
#
#
#
#                   Elektrobit
#
#
#
#
#
#                   Facebook
#
#
#
#
#
#                   Github
#
#
#
#
#
#                   Google
#
#
#
#
#
#                   Google VR
#
#
#
#
#
#                   X
#
#
#
#
#
#                   Gradle
#
#
#
#
#
#                   Georgia Institute of Technology
#
#
#
#
#
#                   Hack Reactor
#
#
#
#
#
#                   Hootsuite
#
#
#
#
#
#                   HubSpot
#
#
#
#
#
#                   IBM
#
#
#
#
#
#                   IBM Watson
#
#
#
#
#
#                   iRobot
#
#
#
#
#
#                   kaggle
#
#
#
#
#
#                   Kuka
#
#
#
#
#
#                   Lockheed Martin
#
#
#
#
#
#                   Lyft
#
#
#
#
#
#                   MailChimp
#
#
#
#
#
#                   McLaren
#
#
#
#
#
#                   Megabots
#
#
#
#
#
#                   Mercedes
#
#
#
#
#
#                   Mode
#
#
#
#
#
#                   MongoDB
#
#
#
#
#
#                   Moz
#
#
#
#
#
#                   NextEv
#
#
#
#
#
#                   Nutanix
#
#
#
#
#
#                   Nvidia
#
#
#
#
#
#                   Pramp
#
#
#
#
#
#                   Salesforce
#
#
#
#
#
#                   Samsung
#
#
#
#
#
#                   San Jose State University
#
#
#
#
#
#                   Tableau
#
#
#
#
#
#                   23andMe
#
#
#
#
#
#                   Twitter
#
#
#
#
#
#                   Uber ATG
#
#
#
#
#
#                   Unity
#
#
#
#
#
#                   Upload Collective
#
#
#
#
#
#                   Venmo
#
#
#
#
#
#                   Vive
#
#
#
#
#
#
#
#
#             Technology
#
#
#
#                   account kit
#
#
#
#
#
#                   ajax
#
#
#
#
#
#                   algorithmic trading
#
#
#
#
#
#                   analytics
#
#
#
#
#
#                   android
#
#
#
#
#
#                   apis
#
#
#
#
#
#                   app
#
#
#
#
#
#                   apps
#
#
#
#
#
#                   asynchronous javascript
#
#
#
#
#
#                   asynchronous requests
#
#
#
#
#
#                   async requests
#
#
#
#
#
#                   bash
#
#
#
#
#
#                   beginner
#
#
#
#
#
#                   big data
#
#
#
#
#
#                   client
#
#
#
#
#
#                   cloud
#
#
#
#
#
#                   collaboration
#
#
#
#
#
#                   command line vcs
#
#
#
#
#
#                   communication
#
#
#
#
#
#                   controller
#
#
#
#
#
#                   css
#
#
#
#
#
#                   d3
#
#
#
#
#
#                   data
#
#
#
#
#
#                   deployment
#
#
#
#
#
#                   design pattern
#
#
#
#
#
#                   development
#
#
#
#
#
#                   ecmascript
#
#
#
#
#
#                   es6
#
#
#
#
#
#                   facebook for developers
#
#
#
#
#
#                   fetch
#
#
#
#
#
#                   finance
#
#
#
#
#
#                   firebase
#
#
#
#
#
#                   fire base
#
#
#
#
#
#                   fork
#
#
#
#
#
#                   fundamentals
#
#
#
#
#
#                   git
#
#
#
#
#
#                   gradle
#
#
#
#
#
#                   hadoop
#
#
#
#
#
#                   hdfs
#
#
#
#
#
#                   heroku
#
#
#
#
#
#                   html
#
#
#
#
#
#                   http
#
#
#
#
#
#                   https
#
#
#
#
#
#                   investment
#
#
#
#
#
#                   ios
#
#
#
#
#
#                   java
#
#
#
#
#
#                   javascript
#
#
#
#
#
#                   jquery
#
#
#
#
#
#                   linux
#
#
#
#
#
#                   machine learning
#
#
#
#
#
#                   mapreduce
#
#
#
#
#
#                   mobile
#
#
#
#
#
#                   model
#
#
#
#
#
#                   mvc
#
#
#
#
#
#                   objective-c
#
#
#
#
#
#                   passwordless login
#
#
#
#
#
#                   programming
#
#
#
#
#
#                   pull request
#
#
#
#
#
#                   python
#
#
#
#
#
#                   r
#
#
#
#
#
#                   rebase
#
#
#
#
#
#                   ruby
#
#
#
#
#
#                   server
#
#
#
#
#
#                   servers
#
#
#
#
#
#                   shell
#
#
#
#
#
#                   sinatra
#
#
#
#
#
#                   sql
#
#
#
#
#
#                   squashing
#
#
#
#
#
#                   swift
#
#
#
#
#
#                   unity
#
#
#
#
#
#                   unreal
#
#
#
#
#
#                   version control
#
#
#
#
#
#                   version control system
#
#
#
#
#
#                   view
#
#
#
#
#
#                   virtual reality
#
#
#
#
#
#                   vr
#
#
#
#
#
#                   web application
#
#
#
#
#
#                   web development
#
#
#
#
#
#                   xhr
#
#
#
#
#
#                   xml
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     All Courses and Nanodegree Programs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd100"] = {
#           "affiliate_ids": ["tableau","mode"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Data Foundations Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Data Foundations Nanodegree
#
#
#               New
#
#
#
#             4 Projects
#
#
#
#
#
#             Beginner
#
#
#
#
#
#         Master data fundamentals applicable to any industry, and learn to make data-driven decisions. Learn Excel and SQL, and gain data visualization skills with Tableau.
#
#
#
#
#
#
#
#
#
#   192
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Tableau, Mode
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd002"] = {
#           "affiliate_ids": ["kaggle","tableau","mode"],
#           "technology_ids": ["hadoop","python","r","d3"],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Data Analyst Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Data Analyst Nanodegree
#
#
#               New
#
#
#
#             22 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         Prepare for a data science career. Learn to use Python, R, SQL, and Tableau to uncover insights, communicate critical findings, and create data-driven solutions.
#
#
#
#
#
#
#
#
#
#   2.98K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               kaggle, Tableau, Mode
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd019"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "React Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               React Nanodegree
#
#
#               New
#
#
#
#             3 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         React is completely transforming Front-End Development. Master this powerful UI library from Facebook with Udacity and the experts from React Training.
#
#
#
#
#
#
#
#
#
#   550
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd000"] = {
#           "affiliate_ids": [],
#           "technology_ids": ["javascript","css","html","python"],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Intro to Programming Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Intro to Programming Nanodegree
#
#
#               New
#
#
#
#             5 Projects
#
#
#
#
#
#             Beginner
#
#
#
#
#
#         Udacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.
#
#
#
#
#
#
#
#
#
#   2.48K
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd017"] = {
#           "affiliate_ids": ["google-vr","vive","Upload","Unity","samsung"],
#           "technology_ids": ["unity","vr","virtual-reality","unreal"],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "VR Developer Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               VR Developer Nanodegree
#
#
#               New
#
#
#
#             13 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         Master the latest tools and technologies, and put your tech skills to work in the exciting field of VR! Learn from industry experts like Google, Unity, and HTC, and become a Virtual Reality Developer.
#
#
#
#
#
#
#
#
#
#   1.7K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Google VR, Vive, Upload Collective, Unity, Samsung
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd209"] = {
#           "affiliate_ids": ["bosch","electric-movement","i-robot","kuka","lockheed-martin","megabots","uber-atg","google-x"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Robotics Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Robotics Nanodegree
#
#
#               New
#
#
#
#             4 Projects
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Master skills with hands-on projects in simulated environments and on real hardware. Change our world for the better using robotics to extend our capabilities in new ways.
#
#
#
#
#
#
#
#
#
#   785
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Bosch, Electric Movement, iRobot, Kuka, Lockheed Martin, Megabots, Uber ATG, X
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd018"] = {
#           "affiliate_ids": ["facebook","google","hootsuite","hubspot","mailchimp","moz"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Digital Marketing Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Digital Marketing Nanodegree
#
#
#               New
#
#
#
#             8 Projects
#
#
#
#
#
#             Beginner
#
#
#
#
#
#         Gain real-world experience running live campaigns as you learn from top experts in the field. Launch your career with a 360-degree understanding of digital marketing.
#
#
#
#
#
#
#
#
#
#   1.17K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Facebook, Google, Hootsuite, HubSpot, MailChimp, Moz
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd101"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Deep Learning Nanodegree Foundation"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Deep Learning Nanodegree Foundation
#
#
#               New
#
#
#
#             5 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         Udacity provides a dynamic introduction to Deep Learning, using weekly videos, exclusive projects, and expert feedback to teach you the foundations of this future-shaping technology.
#
#
#
#
#
#
#
#
#
#   1.99K
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd889"] = {
#           "affiliate_ids": ["ibm-watson","amazon-alexa","didi","affectiva"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Artificial Intelligence Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Artificial Intelligence Nanodegree
#
#
#               New
#
#
#
#             4 Projects
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Learn skills and tools used by the most innovative AI teams, gain experience solving real-world challenges, and prepare for a wide variety of roles in the AI field.
#
#
#
#
#
#
#
#
#
#   2.97K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               IBM Watson, Amazon Alexa, Didi, Affectiva
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd013"] = {
#           "affiliate_ids": ["mercedes","nvidia","uber-atg","didi","nextev","bmw","mclaren"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Self-Driving Car Engineer Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer Nanodegree
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         In this program, you’ll learn the skills and techniques used by self-driving car teams at the most advanced technology companies in the world.
#
#
#
#
#
#
#
#
#
#   1.77K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Mercedes, Nvidia, Uber ATG, Didi, BMW, McLaren, NextEv
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd008"] = {
#           "affiliate_ids": ["5448383925583872","tableau"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Business Analyst Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Business Analyst Nanodegree
#
#
#               New
#
#
#
#             8 Projects
#
#
#
#
#
#             Beginner
#
#
#
#
#
#         Predictive analytics is the practice of determining patterns from data to predict future outcomes and trends. Across industries, it enables high-value solutions to important business problems.
#
#
#
#
#
#
#
#
#
#   2.68K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Alteryx, Tableau
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd803"] = {
#           "affiliate_ids": ["google"],
#           "technology_ids": ["development","mobile","apps","android"],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Android Basics Nanodegree by Google"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Android Basics Nanodegree by Google
#
#
#               New
#
#
#
#             10 Projects
#
#
#
#
#
#             Beginner
#
#
#
#
#
#         Get a solid grasp on the basics of foundational programming skills used in creating mobile apps
#
#
#
#
#
#
#
#
#
#   3.61K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Google
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd009"] = {
#           "affiliate_ids": ["kaggle"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Machine Learning Engineer Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Machine Learning Engineer Nanodegree
#
#
#               New
#
#
#
#             11 Projects
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Become a machine learning engineer and apply predictive models to massive data sets in fields like education, finance, healthcare or robotics.
#
#
#
#
#
#
#
#
#
#   3.26K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               kaggle
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd001"] = {
#           "affiliate_ids": ["att","google","github","hackreactor"],
#           "technology_ids": ["javascript","css","html"],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Front-End Web Developer Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Front-End Web Developer Nanodegree
#
#
#               New
#
#
#
#             7 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         Become a Front-End Web Developer by completing a variety of projects for your portfolio - become an HTML, CSS and JavaScript pro!
#
#
#
#
#
#
#
#
#
#   2.5K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               AT&T, Google, Github, Hack Reactor
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd004"] = {
#           "affiliate_ids": ["amazonwebservices","att","google","github"],
#           "technology_ids": ["sql","python"],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Full Stack Web Developer Nanodegree"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Full Stack Web Developer Nanodegree
#
#
#               New
#
#
#
#             7 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         Learn how to create server-side, data-driven web applications that support any front-end and can scale to support hundreds of thousands of users.
#
#
#
#
#
#
#
#
#
#   2.49K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Amazon Web Services, Github, AT&T, Google
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd801"] = {
#           "affiliate_ids": ["google"],
#           "technology_ids": ["android"],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Android Developer Nanodegree by Google"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Android Developer Nanodegree by Google
#
#
#               New
#
#
#
#             7 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         Start your career as an Android developer. Learn best practices for mobile development, build a portfolio of apps, and publish your own app to Google Play.
#
#
#
#
#
#
#
#
#
#   2.2K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Google
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd003"] = {
#           "affiliate_ids": ["att","lyft","google"],
#           "technology_ids": ["swift"],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Become an iOS Developer"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Become an iOS Developer
#
#
#               New
#
#
#
#             14 Projects
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         Master writing in Swift as you build five portfolio-worthy iOS apps to demonstrate your expertise as an iOS Developer.
#
#
#
#
#
#
#
#
#
#   1.32K
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               AT&T, Lyft, Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
# ...
#               Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx30"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Excel Fundamentals"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Excel Fundamentals
#
#
#               New
#
#
#
#
#
#
#
#
#             Beginner
#
#
#
#
#
#         Learn how to use Microsoft Excel to navigate a spreadsheet, manipulate and summarize data, and create engaging visualizations.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx31"] = {
#           "affiliate_ids": ["nvidia","uber-atg"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Deep Learning"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Deep Learning
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Build and train deep neural networks to classify traffic signs and to drive a car in a simulator.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Nvidia, Uber ATG
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx32"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Computer Vision"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Computer Vision
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Construct computer vision pipelines for lane detection and vehicle tracking.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx33"] = {
#           "affiliate_ids": ["mercedes"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Sensor Fusion"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Sensor Fusion
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Fuse lidar and radar sensor data to track objects over time.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Mercedes
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx34"] = {
#           "affiliate_ids": ["mercedes"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Localization"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Localization
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Pinpoint where your vehicle is with single-digit centimeter level accuracy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Mercedes
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx35"] = {
#           "affiliate_ids": ["uber-atg"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Control"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Control
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Actuate the vehicle using control algorithms of varying levels of complexity.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Uber ATG
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx36"] = {
#           "affiliate_ids": ["mercedes"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Path Planning"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Path Planning
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Path planning for self-driving cars involves three phases: environmental prediction, behavioral planning, and trajectory generation.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Mercedes
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx37"] = {
#           "affiliate_ids": ["nvidia"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Advanced Deep Learning"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Advanced Deep Learning
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Identify free space on the road so that your vehicle can plan the optimal path.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Nvidia
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx38"] = {
#           "affiliate_ids": ["elektrobit"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - Functional Safety"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - Functional Safety
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Ensuring acceptable risk levels in accordance with ISO 26262 requires analysis of entire systems.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             IN COLLABORATION WITH
#
#               Elektrobit
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["cx39"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["advanced"],
#           "other_ids": [],
#           "nodeType_ids": [""],
#           "title": "Self-Driving Car Engineer - System Integration"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Self-Driving Car Engineer - System Integration
#
#
#               New
#
#
#
#
#
#
#
#
#             Advanced
#
#
#
#
#
#         Pull together everything you've learned to operate a real self-driving car.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["ud210"] = {
#           "affiliate_ids": [],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["intermediate"],
#           "other_ids": [],
#           "nodeType_ids": ["Free Course"],
#           "title": "C++ For Programmers"
#         };
#       })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               C++ For Programmers
#
#
#               New
#
#
#
#
#
#
#
#
#             Intermediate
#
#
#
#
#
#         This course teaches C++ to students already familiar with a programming language.
# Students will learn how to use header files, control flow, functions, classes.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               No Matching Courses
#
#
#               Courses matching these results can only be found in an alternate dimension.
#
#               Please modify your search.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Featured Programs
#
#                   Android Basics
#                   Android Developer
#                   Become an iOS Developer
#                   Business Analyst
#                   Data Analyst
#                   Data Foundations
#                   Front-End Web Developer
#                   Full Stack Web Developer
#                   Intro to Programming
#                   React
#
#
#
#             Only At Udacity
#
#                   Artificial Intelligence
#                   Deep Learning Foundations
#                   Digital Marketing
#                   Machine Learning Engineer
#                   Robotics
#                   Self-Driving Car Engineer
#                   VR Developer
#
#
#
#           Resources
#
#             Catalog
#             Career Resource Center
#             Hiring Partners
#             Student Success
#             Udacity Connect
#             Udacity Talks
#             Scholarships
#
#           Programs
#
#             Nanodegree Plus
#             Veterans
#             Georgia Tech
#             Udacity Self-Driving Car
#
#
#
#           Company
#
#             About
#             Blog
#             In the News
#             Jobs
#             Mobile
#             Udacity Intersect
#
#           Business
#
#             Udacity for Business
#             Corporate Training
#             Hire Graduates
#
#
#
#           Support
#
#             Contact Us
#             Help and FAQ
#             Service Status
#             Course Guides
#             Tech Requirements
#             Legal & Privacy
#             Regulatory Information
#             Site Map
#
#
#
#
#
#
#
#           © 2011–2017 Udacity, Inc.
#           Legal & Privacy
#           Regulatory Information
#           Site Map
#
#
#
#
#
#             Brazil
#             China
#             Germany
#             India
#             United States
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       "Nanodegree" is a registered trademark of Udacity. © 2011–2017 Udacity, Inc.
#       Udacity is not an accredited university and we don't confer degrees.
#
#
#
#
#
#     if (!window.jQuery) {
#       var s = document.createElement('script');
#       s.src = '/public/vendor/jquery-1.12.2.min.js';
#       document.body.append(s);
#     }
#
#
#
#     Choose Your Path
#     Select one of the paths below to start exploring learning options
#
#
#
#
#
#
#
#
#
#
#           Nanodegree Programs
#           Best-in-class courses taught by expert instructors
#           Mentoring, project review, and career guidance
#           Certification built and recognized by industry leaders like Google, Facebook, Apple, and more
#
#
#
#
#
#
#
#
#
#
#           Free Courses
#           Best-in-class courses taught by expert instructors
#           Craft your own independent study path
#           Learn the skills to achieve your individual goals
#
#
#     Start Exploring
#
#
#
#     Save Your Bookmarks
#
#
#
#     Create an account to keep your bookmarks.
#
#
#
#           Sign Up
#
#
#
#               Already have an account?
#               Sign in.

# %%
# Find all course summaries
summaries = soup.find_all("div", class_="course-summary-card")
summaries[0]
# Out:
# <div class="course-summary-card row row-gap-medium" data-course-summary="" data-filter-state="show" id="nd100">
#
#     <script>
#       // jshint ignore: start
#       (function() {
#         if (typeof window.nodeHash === 'undefined') { window.nodeHash = {}; }
#         window.nodeHash["nd100"] = {
#           "affiliate_ids": ["tableau","mode"],
#           "technology_ids": [],
#           "legacy": false,
#           "level_ids": ["beginner"],
#           "other_ids": [],
#           "nodeType_ids": ["Nanodegree"],
#           "title": "Data Foundations Nanodegree"
#         };
#       })();
#     </script>
#
#     <div class="col-sm-3">
#       <div class="row">
#         <div class="col-xs-8 col-xs-offset-2 col-sm-12 col-sm-offset-0">
#           <a href="/course/data-foundations-nanodegree--nd100">
#               <img class="img-responsive center-block" data-src="https://s3-us-west-1.amazonaws.com/udacity-content/degrees/catalog-images/Data-Analyst.png" height="152" src="" width="290"/>
#           </a>
#         </div>
#       </div>
#     </div>
#     <div class="col-sm-9">
#       <div class="row">
#         <div class="col-sm-8">
#           <h3 class="h-slim">
#             <a data-course-title="" href="/course/data-foundations-nanodegree--nd100">
#               Data Foundations Nanodegree
#             </a>
#             <span class="badges">
#               <span class="badge badge-squared badge-new text-uppercase">New</span>
#             </span>
#           </h3>
#
#             <span class="h4">4 Projects</span>
#
#         </div>
#         <div class="col-sm-4 hidden-xs">
#           <span class="caption text-right">
#             <span class="icon-level course-info-bar-icon icon-level-beginner" data-course-level-icon=""></span>
#             <span data-course-level-label="">Beginner</span>
#           </span>
#         </div>
#       </div>
#
#       <div data-course-short-summary="">
#         Master data fundamentals applicable to any industry, and learn to make data-driven decisions. Learn Excel and SQL, and gain data visualization skills with Tableau.
#       </div>
#
#       <p class="clearfix">
#         <span class="course-bookmark-button pull-right" data-course-bookmark-button="">
#
#
#
# <a class="bookmark-button hide" data-bookmarked="false" data-cta="#bookmarks-catalog-modal" data-key="nd100" data-tooltip-add="Add to Bookmarks" data-tooltip-archive="Remove from Bookmarks" data-type="nanodegree" href="javascript:void(0);" id="ga-186170" title="Add to Bookmarks">
#
#   <span class="count loading" data-bookmark-count="192">192</span>
#   <span class="star"></span>
# </a>
#         </span>
#
#         <span data-course-affiliates-wrapper="">
#             <span class="h4" data-course-affiliates-label="">IN COLLABORATION WITH</span>
#             <strong data-course-affiliates-list="">
#               Tableau, Mode
#             </strong>
#         </span>
#       </p>
#     </div>
#     <hr class="hidden-sm"/>
#   </div>

# %%
# Extract title
summaries[0].select_one("h3 a").get_text().strip()
# Out:
# 'Data Foundations Nanodegree'

# %%
# Extract description
summaries[0].select_one("div[data-course-short-summary]").get_text().strip()
# Out:
# 'Master data fundamentals applicable to any industry, and learn to make data-driven decisions. Learn Excel and SQL, and gain data visualization skills with Tableau.'

# %%
# Find all course summaries, extract title and description
courses = []
summaries = soup.find_all("div", class_="course-summary-card")
for summary in summaries:
    title = summary.select_one("h3 a").get_text().strip()
    description = summary.select_one("div[data-course-short-summary]").get_text().strip()
    courses.append((title, description))

print(len(courses), "course summaries found. Sample:")
print(courses[0][0])
print(courses[0][1])
# Out:
# 228 course summaries found. Sample:
# Data Foundations Nanodegree
# Master data fundamentals applicable to any industry, and learn to make data-driven decisions. Learn Excel and SQL, and gain data visualization skills with Tableau.

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.']

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Dr. Smith graduated from the University of Washington.', 'He later started an analytics firm called Lux, which catered to enterprise customers.']

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'ones', 'started', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ## Part-of-Speech Tagging

# %%
from nltk import pos_tag

# Tag parts of speech (PoS)
sentence = word_tokenize("I always lie down to tell a lie.")
pos_tag(sentence)
# Out:
# [('I', 'PRP'),
#  ('always', 'RB'),
#  ('lie', 'VBP'),
#  ('down', 'RP'),
#  ('to', 'TO'),
#  ('tell', 'VB'),
#  ('a', 'DT'),
#  ('lie', 'NN'),
#  ('.', '.')]

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
import IPython  # for displaying parse trees inline

# Visualize parse trees
for tree in parser.parse(sentence):
    IPython.display.display(tree)  # instead of tree.draw()
# Out:
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant'])])]), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant']), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])])

# %%
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

# Recognize named entities in a tagged sentence
tree = ne_chunk(pos_tag(word_tokenize("Antonio joined Udacity Inc. in California.")))
IPython.display.display(tree)
# Out:
# Tree('S', [Tree('PERSON', [('Antonio', 'NNP')]), ('joined', 'VBD'), Tree('ORGANIZATION', [('Udacity', 'NNP'), ('Inc.', 'NNP')]), ('in', 'IN'), Tree('GPE', [('California', 'NNP')]), ('.', '.')])

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaiss', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definit', 'watch', 'part', '2', 'chang', 'view', 'matrix', 'human', 'peopl', 'one', 'start', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'started', 'war', 'ai', 'bad', 'thing']

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'start', 'war', 'ai', 'bad', 'thing']
