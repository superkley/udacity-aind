# %% [markdown]
# # NLP: Machine Translation Project
#
# > Udacity Artificial Intelligence Engineer Nanodegree: NLP Project 3
# >
# > Author: Ke Zhang
# >
# > Submission Date: 2017-10-10 (Revision 1)

# %% [markdown]
# ## Introduction
# In this notebook, you will build a deep neural network that functions as part of an end-to-end machine translation pipeline. Your completed pipeline will accept English text as input and return the French translation.
#
# - **Preprocess** - You'll convert text to sequence of integers.
# - **Models** Create models which accepts a sequence of integers as input and returns a probability distribution over possible translations. After learning about the basic types of neural networks that are often used for machine translation, you will engage in your own investigations, to design your own model!
# - **Prediction** Run the model on English text.
#
# ## Dataset
# We begin by investigating the dataset that will be used to train and evaluate your pipeline.  The most common datasets used for machine translation are from [WMT](http://www.statmt.org/).  However, that will take a long time to train a neural network on.  We'll be using a dataset we created for this project that contains a small vocabulary.  You'll be able to train your model in a reasonable time with this dataset.
# ### Load Data
# The data is located in `data/small_vocab_en` and `data/small_vocab_fr`. The `small_vocab_en` file contains English sentences with their French translations in the `small_vocab_fr` file. Load the English and French data from these files from running the cell below.

# %%
import helper


# Load English data
english_sentences = helper.load_data('data/small_vocab_en')
# Load French data
french_sentences = helper.load_data('data/small_vocab_fr')

print('Dataset Loaded')
# Out:
# Dataset Loaded

# %% [markdown]
# ### Files
# Each line in `small_vocab_en` contains an English sentence with the respective translation in each line of `small_vocab_fr`.  View the first two lines from each file.

# %%
for sample_i in range(2):
    print('small_vocab_en Line {}:  {}'.format(sample_i + 1, english_sentences[sample_i]))
    print('small_vocab_fr Line {}:  {}'.format(sample_i + 1, french_sentences[sample_i]))
# Out:
# small_vocab_en Line 1:  new jersey is sometimes quiet during autumn , and it is snowy in april .
# small_vocab_fr Line 1:  new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# small_vocab_en Line 2:  the united states is usually chilly during july , and it is usually freezing in november .
# small_vocab_fr Line 2:  les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .

# %% [markdown]
# From looking at the sentences, you can see they have been preprocessed already.  The puncuations have been delimited using spaces. All the text have been converted to lowercase.  This should save you some time, but the text requires more preprocessing.
# ### Vocabulary
# The complexity of the problem is determined by the complexity of the vocabulary.  A more complex vocabulary is a more complex problem.  Let's look at the complexity of the dataset we'll be working with.

# %%
import collections

english_words_counter = collections.Counter([word for sentence in english_sentences for word in sentence.split()])
french_words_counter = collections.Counter([word for sentence in french_sentences for word in sentence.split()])

print('{} English words.'.format(len([word for sentence in english_sentences for word in sentence.split()])))
print('{} unique English words.'.format(len(english_words_counter)))
print('10 Most common words in the English dataset:')
print('"' + '" "'.join(list(zip(*english_words_counter.most_common(10)))[0]) + '"')
print()
print('{} French words.'.format(len([word for sentence in french_sentences for word in sentence.split()])))
print('{} unique French words.'.format(len(french_words_counter)))
print('10 Most common words in the French dataset:')
print('"' + '" "'.join(list(zip(*french_words_counter.most_common(10)))[0]) + '"')
# Out:
# 1823250 English words.
# 227 unique English words.
# 10 Most common words in the English dataset:
# "is" "," "." "in" "it" "during" "the" "but" "and" "sometimes"
#
# 1961295 French words.
# 355 unique French words.
# 10 Most common words in the French dataset:
# "est" "." "," "en" "il" "les" "mais" "et" "la" "parfois"

# %% [markdown]
# For comparison, _Alice's Adventures in Wonderland_ contains 2,766 unique words of a total of 15,500 words.
# ## Preprocess
# For this project, you won't use text data as input to your model. Instead, you'll convert the text into sequences of integers using the following preprocess methods:
# 1. Tokenize the words into ids
# 2. Add padding to make all the sequences the same length.
#
# Time to start preprocessing the data...
# ### Tokenize (IMPLEMENTATION)
# For a neural network to predict on text data, it first has to be turned into data it can understand. Text data like "dog" is a sequence of ASCII character encodings.  Since a neural network is a series of multiplication and addition operations, the input data needs to be number(s).
#
# We can turn each character into a number or each word into a number.  These are called character and word ids, respectively.  Character ids are used for character level models that generate text predictions for each character.  A word level model uses word ids that generate text predictions for each word.  Word level models tend to learn better, since they are lower in complexity, so we'll use those.
#
# Turn each sentence into a sequence of words ids using Keras's [`Tokenizer`](https://keras.io/preprocessing/text/#tokenizer) function. Use this function to tokenize `english_sentences` and `french_sentences` in the cell below.
#
# Running the cell will run `tokenize` on sample data and show output for debugging.

# %%
import project_tests as tests
from keras.preprocessing.text import Tokenizer


def tokenize(x):
    """
    Tokenize x
    :param x: List of sentences/strings to be tokenized
    :return: Tuple of (tokenized x data, tokenizer used to tokenize x)
    """
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(x)
    tokenized_data = tokenizer.texts_to_sequences(x)
    return tokenized_data, tokenizer

tests.test_tokenize(tokenize)

# Tokenize Example output
text_sentences = [
    'The quick brown fox jumps over the lazy dog .',
    'By Jove , my quick study of lexicography won a prize .',
    'This is a short sentence .']
text_tokenized, text_tokenizer = tokenize(text_sentences)
print(text_tokenizer.word_index)
print()
for sample_i, (sent, token_sent) in enumerate(zip(text_sentences, text_tokenized)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(sent))
    print('  Output: {}'.format(token_sent))
# Out:
# {'fox': 5, 'prize': 17, 'short': 20, 'won': 16, 'study': 13, 'over': 7, 'of': 14, 'sentence': 21, 'by': 10, 'jove': 11, 'my': 12, 'jumps': 6, 'brown': 4, 'lexicography': 15, 'a': 3, 'this': 18, 'the': 1, 'quick': 2, 'lazy': 8, 'is': 19, 'dog': 9}
#
# Sequence 1 in x
#   Input:  The quick brown fox jumps over the lazy dog .
#   Output: [1, 2, 4, 5, 6, 7, 1, 8, 9]
# Sequence 2 in x
#   Input:  By Jove , my quick study of lexicography won a prize .
#   Output: [10, 11, 12, 2, 13, 14, 15, 16, 3, 17]
# Sequence 3 in x
#   Input:  This is a short sentence .
#   Output: [18, 19, 3, 20, 21]

# %% [markdown]
# ### Padding (IMPLEMENTATION)
# When batching the sequence of word ids together, each sequence needs to be the same length.  Since sentences are dynamic in length, we can add padding to the end of the sequences to make them the same length.
#
# Make sure all the English sequences have the same length and all the French sequences have the same length by adding padding to the **end** of each sequence using Keras's [`pad_sequences`](https://keras.io/preprocessing/sequence/#pad_sequences) function.

# %%
import numpy as np
from keras.preprocessing.sequence import pad_sequences


def pad(x, length=None):
    """
    Pad x
    :param x: List of sequences.
    :param length: Length to pad the sequence to.  If None, use length of longest sequence in x.
    :return: Padded numpy array of sequences
    """
    padder = pad_sequences(x, maxlen=length, padding='post')
    return padder

tests.test_pad(pad)

# Pad Tokenized output
test_pad = pad(text_tokenized)
for sample_i, (token_sent, pad_sent) in enumerate(zip(text_tokenized, test_pad)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(np.array(token_sent)))
    print('  Output: {}'.format(pad_sent))
# Out:
# Sequence 1 in x
#   Input:  [1 2 4 5 6 7 1 8 9]
#   Output: [1 2 4 5 6 7 1 8 9 0]
# Sequence 2 in x
#   Input:  [10 11 12  2 13 14 15 16  3 17]
#   Output: [10 11 12  2 13 14 15 16  3 17]
# Sequence 3 in x
#   Input:  [18 19  3 20 21]
#   Output: [18 19  3 20 21  0  0  0  0  0]

# %% [markdown]
# ### Preprocess Pipeline
# Your focus for this project is to build neural network architecture, so we won't ask you to create a preprocess pipeline.  Instead, we've provided you with the implementation of the `preprocess` function.

# %%
def preprocess(x, y):
    """
    Preprocess x and y
    :param x: Feature List of sentences
    :param y: Label List of sentences
    :return: Tuple of (Preprocessed x, Preprocessed y, x tokenizer, y tokenizer)
    """
    preprocess_x, x_tk = tokenize(x)
    preprocess_y, y_tk = tokenize(y)

    preprocess_x = pad(preprocess_x)
    preprocess_y = pad(preprocess_y)

    # Keras's sparse_categorical_crossentropy function requires the labels to be in 3 dimensions
    preprocess_y = preprocess_y.reshape(*preprocess_y.shape, 1)

    return preprocess_x, preprocess_y, x_tk, y_tk

preproc_english_sentences, preproc_french_sentences, english_tokenizer, french_tokenizer =\
    preprocess(english_sentences, french_sentences)

print('Data Preprocessed')
print('- English sentences preprocessed: {}'.format(preproc_english_sentences.shape))
print('- English vocabulary size: {}'.format(len(english_tokenizer.word_index)))
print('- French sentences preprocessed: {}'.format(preproc_french_sentences.shape))
print('- French vocabulary size: {}'.format(len(french_tokenizer.word_index)))
# Out:
# Data Preprocessed
# - English sentences preprocessed: (137861, 15)
# - English vocabulary size: 199
# - French sentences preprocessed: (137861, 21, 1)
# - French vocabulary size: 344

# %% [markdown]
# ## Models
# In this section, you will experiment with various neural network architectures.
# You will begin by training four relatively simple architectures.
# - Model 1 is a simple RNN
# - Model 2 is a RNN with Embedding
# - Model 3 is a Bidirectional RNN
# - Model 4 is an optional Encoder-Decoder RNN
#
# After experimenting with the four simple architectures, you will construct a deeper architecture that is designed to outperform all four models.
# ### Ids Back to Text
# The neural network will be translating the input to words ids, which isn't the final form we want.  We want the French translation.  The function `logits_to_text` will bridge the gab between the logits from the neural network to the French translation.  You'll be using this function to better understand the output of the neural network.

# %%
def logits_to_text(logits, tokenizer):
    """
    Turn logits from a neural network into text using the tokenizer
    :param logits: Logits from a neural network
    :param tokenizer: Keras Tokenizer fit on the labels
    :return: String that represents the text of the logits
    """
    index_to_words = {id: word for word, id in tokenizer.word_index.items()}
    index_to_words[0] = '<PAD>'

    return ' '.join([index_to_words[prediction] for prediction in np.argmax(logits, 1)])

print('`logits_to_text` function loaded.')
# Out:
# `logits_to_text` function loaded.

# %%
print('French max index: {}'.format(max([w[0][0] for w in preproc_french_sentences])))
print('English max index: {}'.format(max([w[0] for w in preproc_english_sentences])))
# Out:
# French max index: 343
# English max index: 199

# %% [markdown]
# ### Model 1: RNN (IMPLEMENTATION)
# ![RNN](images/rnn.png)
# A basic RNN model is a good baseline for sequence data.  In this model, you'll build a RNN that translates English to French.

# %%
from keras.layers import GRU, Input, Dense, TimeDistributed
from keras.models import Model
from keras.layers import Activation
from keras.optimizers import Adam
from keras.losses import sparse_categorical_crossentropy

def simple_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a basic RNN on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    print('input-shape: {}'.format(input_shape))
    print('output-length: {}'.format(output_sequence_length))
    print('english vocab size: {}'.format(english_vocab_size))
    print('french vocab size: {}'.format(french_vocab_size))
    # build the layers
    learning_rate = .001
    inputs = Input(shape=input_shape[1:])
    layers = GRU(output_sequence_length,recurrent_dropout=0.2,
                 return_sequences=True)(inputs)
    layers = TimeDistributed(Dense(2 * french_vocab_size, 
                                    activation='relu'))(layers)
    outputs = TimeDistributed(Dense(french_vocab_size, 
                                    activation='softmax'))(layers)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    print(model.summary())
    return model

tests.test_simple_model(simple_model)

# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, preproc_french_sentences.shape[1])
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2], 1))

# Train the neural network
simple_rnn_model = simple_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index) + 1,
    len(french_tokenizer.word_index) + 1)
simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=10, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(simple_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# input-shape: (137861, 21, 1)
# output-length: 21
# english vocab size: 199
# french vocab size: 344
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21, 1)             0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 21, 21)            1449
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 21, 688)           15136
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 21, 344)           237016
# =================================================================
# Total params: 253,601
# Trainable params: 253,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# input-shape: (137861, 21, 1)
# output-length: 21
# english vocab size: 200
# french vocab size: 345
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 21, 1)             0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 21, 21)            1449
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 21, 690)           15180
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 21, 345)           238395
# =================================================================
# Total params: 255,024
# Trainable params: 255,024
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/10
# 110288/110288 [==============================] - 903s - loss: 3.2372 - acc: 0.4429 - val_loss: 2.3496 - val_acc: 0.4896
# Epoch 2/10
# 110288/110288 [==============================] - 885s - loss: 2.1902 - acc: 0.5058 - val_loss: 2.0000 - val_acc: 0.5420
# Epoch 3/10
# 110288/110288 [==============================] - 918s - loss: 1.9082 - acc: 0.5489 - val_loss: 1.7740 - val_acc: 0.5666
# Epoch 4/10
# 110288/110288 [==============================] - 1229s - loss: 1.7310 - acc: 0.5714 - val_loss: 1.6207 - val_acc: 0.5879
# Epoch 5/10
# 110288/110288 [==============================] - 1333s - loss: 1.6098 - acc: 0.5871 - val_loss: 1.5205 - val_acc: 0.6068
# Epoch 6/10
# 110288/110288 [==============================] - 1351s - loss: 1.5266 - acc: 0.5987 - val_loss: 1.4525 - val_acc: 0.6131
# Epoch 7/10
# 110288/110288 [==============================] - 1291s - loss: 1.4679 - acc: 0.6065 - val_loss: 1.4019 - val_acc: 0.6175
# Epoch 8/10
# 110288/110288 [==============================] - 666s - loss: 1.4229 - acc: 0.6119 - val_loss: 1.3626 - val_acc: 0.6237
# Epoch 9/10
# 110288/110288 [==============================] - 510s - loss: 1.3869 - acc: 0.6180 - val_loss: 1.3336 - val_acc: 0.6282
# Epoch 10/10
# 110288/110288 [==============================] - 401s - loss: 1.3574 - acc: 0.6231 - val_loss: 1.3061 - val_acc: 0.6395
# new jersey est parfois parfois en en et il est est en en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 2: Embedding (IMPLEMENTATION)
# ![RNN](images/embedding.png)
# You've turned the words into ids, but there's a better representation of a word.  This is called word embeddings.  An embedding is a vector representation of the word that is close to similar words in n-dimensional space, where the n represents the size of the embedding vectors.
#
# In this model, you'll create a RNN model using embedding.

# %%
from keras.layers.embeddings import Embedding


def embed_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a RNN model using word embedding on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # build the layers
    learning_rate = .001
    inputs = Input(shape=input_shape[1:])
    layers = Embedding(english_vocab_size, english_vocab_size)(inputs)
    layers = GRU(output_sequence_length, recurrent_dropout=0.2,
        return_sequences=True)(layers)
    layers = TimeDistributed(Dense(2 * french_vocab_size, 
                                    activation='relu'))(layers)
    outputs = TimeDistributed(Dense(french_vocab_size, 
                                    activation='softmax'))(layers)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    print(model.summary())
    return model

tests.test_embed_model(embed_model)

# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, preproc_french_sentences.shape[1])

# Train the neural network
embed_rnn_model = embed_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index) + 1,
    len(french_tokenizer.word_index) + 1)

embed_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, 
                    epochs=10, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(embed_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 21, 199)           39601
# _________________________________________________________________
# gru_3 (GRU)                  (None, 21, 21)            13923
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 21, 688)           15136
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 21, 344)           237016
# =================================================================
# Total params: 305,676
# Trainable params: 305,676
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 21, 200)           40000
# _________________________________________________________________
# gru_4 (GRU)                  (None, 21, 21)            13986
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 21, 690)           15180
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 21, 345)           238395
# =================================================================
# Total params: 307,561
# Trainable params: 307,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/10
# 110288/110288 [==============================] - 298s - loss: 2.9432 - acc: 0.4961 - val_loss: 1.6575 - val_acc: 0.6092
# Epoch 2/10
# 110288/110288 [==============================] - 319s - loss: 1.2783 - acc: 0.6648 - val_loss: 1.0384 - val_acc: 0.7012
# Epoch 3/10
# 110288/110288 [==============================] - 297s - loss: 0.9519 - acc: 0.7104 - val_loss: 0.8566 - val_acc: 0.7290
# Epoch 4/10
# 110288/110288 [==============================] - 299s - loss: 0.8194 - acc: 0.7328 - val_loss: 0.7518 - val_acc: 0.7510
# Epoch 5/10
# 110288/110288 [==============================] - 307s - loss: 0.7282 - acc: 0.7561 - val_loss: 0.6614 - val_acc: 0.7792
# Epoch 6/10
# 110288/110288 [==============================] - 289s - loss: 0.6511 - acc: 0.7835 - val_loss: 0.5941 - val_acc: 0.8032
# Epoch 7/10
# 110288/110288 [==============================] - 347s - loss: 0.5993 - acc: 0.8012 - val_loss: 0.5525 - val_acc: 0.8186
# Epoch 8/10
# 110288/110288 [==============================] - 318s - loss: 0.5622 - acc: 0.8135 - val_loss: 0.5204 - val_acc: 0.8291
# Epoch 9/10
# 110288/110288 [==============================] - 312s - loss: 0.5318 - acc: 0.8232 - val_loss: 0.4944 - val_acc: 0.8355
# Epoch 10/10
# 110288/110288 [==============================] - 307s - loss: 0.5070 - acc: 0.8312 - val_loss: 0.4733 - val_acc: 0.8423
# new jersey est parfois calme en cours et il est neigeux neigeux avril avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 3: Bidirectional RNNs (IMPLEMENTATION)
# ![RNN](images/bidirectional.png)
# One restriction of a RNN is that it can't see the future input, only the past.  This is where bidirectional recurrent neural networks come in.  They are able to see the future data.

# %%
from keras.layers import Bidirectional


def bd_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a bidirectional RNN model on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # build the layers
    learning_rate = .001
    inputs = Input(shape=input_shape[1:])
    layers = Bidirectional(GRU(output_sequence_length, recurrent_dropout=0.2,
        return_sequences=True))(inputs)
    layers = TimeDistributed(Dense(2 * french_vocab_size, 
                                    activation='relu'))(layers)
    outputs = TimeDistributed(Dense(french_vocab_size, 
                                    activation='softmax'))(layers)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    print(model.summary())
    return model

tests.test_bd_model(bd_model)

# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, preproc_french_sentences.shape[1])
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2], 1))

# Train the neural network
bd_rnn_model = bd_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index) + 1,
    len(french_tokenizer.word_index) + 1)

bd_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, 
                    epochs=10, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(bd_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 21, 1)             0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 21, 42)            2898
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 21, 688)           29584
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 21, 344)           237016
# =================================================================
# Total params: 269,498
# Trainable params: 269,498
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 21, 1)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 21, 42)            2898
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 21, 690)           29670
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 21, 345)           238395
# =================================================================
# Total params: 270,963
# Trainable params: 270,963
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/10
# 110288/110288 [==============================] - 342s - loss: 3.0607 - acc: 0.4825 - val_loss: 2.0203 - val_acc: 0.5461
# Epoch 2/10
# 110288/110288 [==============================] - 302s - loss: 1.8057 - acc: 0.5692 - val_loss: 1.6009 - val_acc: 0.5908
# Epoch 3/10
# 110288/110288 [==============================] - 305s - loss: 1.5459 - acc: 0.5961 - val_loss: 1.4496 - val_acc: 0.6138
# Epoch 4/10
# 110288/110288 [==============================] - 304s - loss: 1.4368 - acc: 0.6116 - val_loss: 1.3647 - val_acc: 0.6285
# Epoch 5/10
# 110288/110288 [==============================] - 320s - loss: 1.3693 - acc: 0.6221 - val_loss: 1.3081 - val_acc: 0.6407
# Epoch 6/10
# 110288/110288 [==============================] - 319s - loss: 1.3201 - acc: 0.6304 - val_loss: 1.2631 - val_acc: 0.6464
# Epoch 7/10
# 110288/110288 [==============================] - 301s - loss: 1.2809 - acc: 0.6370 - val_loss: 1.2288 - val_acc: 0.6504
# Epoch 8/10
# 110288/110288 [==============================] - 302s - loss: 1.2484 - acc: 0.6421 - val_loss: 1.1994 - val_acc: 0.6561
# Epoch 9/10
# 110288/110288 [==============================] - 308s - loss: 1.2219 - acc: 0.6466 - val_loss: 1.1758 - val_acc: 0.6583
# Epoch 10/10
# 110288/110288 [==============================] - 281s - loss: 1.1986 - acc: 0.6509 - val_loss: 1.1541 - val_acc: 0.6632
# new jersey est parfois humide en en et il est est en en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 4: Encoder-Decoder (OPTIONAL)
# Time to look at encoder-decoder models.  This model is made up of an encoder and decoder. The encoder creates a matrix representation of the sentence.  The decoder takes this matrix as input and predicts the translation as output.
#
# Create an encoder-decoder model in the cell below.

# %%
from keras.layers import RepeatVector


def encdec_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train an encoder-decoder model on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # build the layers
    learning_rate = .001
    inputs = Input(shape=input_shape[1:])
    layers = GRU(output_sequence_length)(inputs)
    layers = RepeatVector(output_sequence_length)(layers)
    layers = GRU(output_sequence_length, recurrent_dropout=0.2,
                return_sequences=True)(layers)
    layers = TimeDistributed(Dense(2 * french_vocab_size, 
                                    activation='relu'))(layers)
    outputs = TimeDistributed(Dense(french_vocab_size, 
                                    activation='softmax'))(layers)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    print(model.summary())
    return model

tests.test_encdec_model(encdec_model)

# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, preproc_french_sentences.shape[1])
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2], 1))

# Train the neural network
encdec_rnn_model = encdec_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index) + 1,
    len(french_tokenizer.word_index) + 1)

encdec_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, 
                    epochs=10, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(encdec_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 15, 1)             0
# _________________________________________________________________
# gru_7 (GRU)                  (None, 21)                1449
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 21, 21)            0
# _________________________________________________________________
# gru_8 (GRU)                  (None, 21, 21)            2709
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 21, 688)           15136
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 21, 344)           237016
# =================================================================
# Total params: 256,310
# Trainable params: 256,310
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 21, 1)             0
# _________________________________________________________________
# gru_9 (GRU)                  (None, 21)                1449
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 21, 21)            0
# _________________________________________________________________
# gru_10 (GRU)                 (None, 21, 21)            2709
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 21, 690)           15180
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 21, 345)           238395
# =================================================================
# Total params: 257,733
# Trainable params: 257,733
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/10
# 110288/110288 [==============================] - 270s - loss: 3.7417 - acc: 0.4044 - val_loss: 2.9581 - val_acc: 0.4093
# Epoch 2/10
# 110288/110288 [==============================] - 281s - loss: 2.8185 - acc: 0.4292 - val_loss: 2.5114 - val_acc: 0.4579
# Epoch 3/10
# 110288/110288 [==============================] - 270s - loss: 2.3950 - acc: 0.4730 - val_loss: 2.2074 - val_acc: 0.4995
# Epoch 4/10
# 110288/110288 [==============================] - 269s - loss: 2.1709 - acc: 0.5085 - val_loss: 2.0707 - val_acc: 0.5233
# Epoch 5/10
# 110288/110288 [==============================] - 267s - loss: 2.0503 - acc: 0.5198 - val_loss: 1.9726 - val_acc: 0.5261
# Epoch 6/10
# 110288/110288 [==============================] - 269s - loss: 1.9579 - acc: 0.5288 - val_loss: 1.8329 - val_acc: 0.5473
# Epoch 7/10
# 110288/110288 [==============================] - 268s - loss: 1.7915 - acc: 0.5477 - val_loss: 1.7107 - val_acc: 0.5596
# Epoch 8/10
# 110288/110288 [==============================] - 269s - loss: 1.7186 - acc: 0.5557 - val_loss: 1.6627 - val_acc: 0.5691
# Epoch 9/10
# 110288/110288 [==============================] - 268s - loss: 1.6769 - acc: 0.5613 - val_loss: 1.6326 - val_acc: 0.5714
# Epoch 10/10
# 110288/110288 [==============================] - 269s - loss: 1.6434 - acc: 0.5674 - val_loss: 1.6063 - val_acc: 0.5782
# la est est parfois en en et il il est est en en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 5: Custom (IMPLEMENTATION)
# Use everything you learned from the previous models to create a model that incorporates embedding and a bidirectional rnn into one model.

# %%
from keras.layers import GRU, Input, Dense, TimeDistributed
from keras.models import Model
from keras.layers import Activation, Bidirectional,RepeatVector
from keras.optimizers import Adam
from keras.losses import sparse_categorical_crossentropy
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers.embeddings import Embedding

def model_final(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a model that incorporates embedding, encoder-decoder, and bidirectional RNN on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # build the layers
    learning_rate = .005
    inputs = Input(shape=input_shape[1:])
    layers = Embedding(english_vocab_size, english_vocab_size, 
                       mask_zero=False)(inputs)
    layers = Bidirectional(GRU(256, dropout=0.5, recurrent_dropout=0.5))(layers)
    layers = RepeatVector(output_sequence_length)(layers)
    layers = Bidirectional(GRU(256, dropout=0.5, recurrent_dropout=0.5,
                               return_sequences=True))(layers)
    layers = TimeDistributed(Dense(4 * french_vocab_size, activation='relu'))(layers)
    layers = TimeDistributed(Dense(2 * french_vocab_size, activation='relu'))(layers)
    outputs = TimeDistributed(Dense(french_vocab_size, activation='softmax'))(layers)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    print(model.summary())
    return model

tests.test_model_final(model_final)

print('Final Model Loaded')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 15)                0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 15, 199)           39601
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 512)               700416
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 21, 512)           0
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 21, 512)           1181184
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 21, 1376)          705888
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 21, 688)           947376
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 21, 344)           237016
# =================================================================
# Total params: 3,811,481
# Trainable params: 3,811,481
# Non-trainable params: 0
# _________________________________________________________________
# None
# Final Model Loaded

# %% [markdown]
# ## Prediction (IMPLEMENTATION)

# %%
import numpy as np
import os.path
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
model_file = 'final_model.h5'

def fit_model(model, x, y):
    # Reserve/specify some training data for validation (not to be used for training)
    checkpoint = ModelCheckpoint(filepath=model_file, 
                                   monitor='val_loss',
                                   save_best_only=True, 
                                   verbose=1)
    earlystop = EarlyStopping(monitor='val_loss', patience=5)    
    model.fit(x, y, batch_size=1024, 
                epochs=100, validation_split=0.2, 
                callbacks=[checkpoint, earlystop],
                verbose=2)

def final_predictions(x, y, x_tk, y_tk):
    """
    Gets predictions using the final model
    :param x: Preprocessed English data
    :param y: Preprocessed French data
    :param x_tk: English tokenizer
    :param y_tk: French tokenizer
    """
    x = pad(x, y.shape[1])
    if os.path.isfile(model_file):        
        print('Continue with last save: {}'.format(model_file))
        model = load_model(model_file)
    else:
        # Train neural network using model_final
        model = model_final(
            x.shape,
            y.shape[1],
            len(x_tk.word_index) + 1,
            len(y_tk.word_index) + 1)
    fit_model(model, x, y)

    # Print prediction(s)
    print(logits_to_text(model.predict(x[:1])[0], y_tk))
    
    ## DON'T EDIT ANYTHING BELOW THIS LINE
    y_id_to_word = {value: key for key, value in y_tk.word_index.items()}
    y_id_to_word[0] = '<PAD>'

    sentence = 'he saw a old yellow truck'
    sentence = [x_tk.word_index[word] for word in sentence.split()]
    sentence = pad_sequences([sentence], maxlen=x.shape[-1], padding='post')
    sentences = np.array([sentence[0], x[0]])
    predictions = model.predict(sentences, len(sentences))

    print('Sample 1:')
    print(' '.join([y_id_to_word[np.argmax(x)] for x in predictions[0]]))
    print('Il a vu un vieux camion jaune')
    print('Sample 2:')
    print(' '.join([y_id_to_word[np.argmax(x)] for x in predictions[1]]))
    print(' '.join([y_id_to_word[np.argmax(x)] for x in y[0]]))


final_predictions(preproc_english_sentences, preproc_french_sentences, english_tokenizer, french_tokenizer)
# Out:
# Continue with last save: final_model.h5
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 0.90126, saving model to final_model.h5
# 920s - loss: 0.9952 - acc: 0.7142 - val_loss: 0.9013 - val_acc: 0.7392
# Epoch 2/100
# Epoch 00001: val_loss improved from 0.90126 to 0.89123, saving model to final_model.h5
# 755s - loss: 0.9735 - acc: 0.7193 - val_loss: 0.8912 - val_acc: 0.7441
# Epoch 3/100
# Epoch 00002: val_loss improved from 0.89123 to 0.84717, saving model to final_model.h5
# 747s - loss: 0.9490 - acc: 0.7251 - val_loss: 0.8472 - val_acc: 0.7552
# Epoch 4/100
# Epoch 00003: val_loss improved from 0.84717 to 0.82363, saving model to final_model.h5
# 750s - loss: 0.9316 - acc: 0.7292 - val_loss: 0.8236 - val_acc: 0.7617
# Epoch 5/100
# Epoch 00004: val_loss improved from 0.82363 to 0.80547, saving model to final_model.h5
# 747s - loss: 0.9121 - acc: 0.7336 - val_loss: 0.8055 - val_acc: 0.7659
# Epoch 6/100
# Epoch 00005: val_loss improved from 0.80547 to 0.78199, saving model to final_model.h5
# 753s - loss: 0.8929 - acc: 0.7369 - val_loss: 0.7820 - val_acc: 0.7677
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 746s - loss: 0.8717 - acc: 0.7413 - val_loss: 0.7876 - val_acc: 0.7650
# Epoch 8/100
# Epoch 00007: val_loss improved from 0.78199 to 0.76591, saving model to final_model.h5
# 745s - loss: 0.8530 - acc: 0.7452 - val_loss: 0.7659 - val_acc: 0.7697
# Epoch 9/100
# Epoch 00008: val_loss improved from 0.76591 to 0.76322, saving model to final_model.h5
# 756s - loss: 0.8367 - acc: 0.7485 - val_loss: 0.7632 - val_acc: 0.7713
# Epoch 10/100
# Epoch 00009: val_loss improved from 0.76322 to 0.71439, saving model to final_model.h5
# 761s - loss: 0.8203 - acc: 0.7526 - val_loss: 0.7144 - val_acc: 0.7834
# Epoch 11/100
# Epoch 00010: val_loss improved from 0.71439 to 0.70487, saving model to final_model.h5
# 751s - loss: 0.8057 - acc: 0.7562 - val_loss: 0.7049 - val_acc: 0.7876
# Epoch 12/100
# Epoch 00011: val_loss improved from 0.70487 to 0.67946, saving model to final_model.h5
# 749s - loss: 0.7866 - acc: 0.7612 - val_loss: 0.6795 - val_acc: 0.7954
# Epoch 13/100
# Epoch 00012: val_loss improved from 0.67946 to 0.65951, saving model to final_model.h5
# 748s - loss: 0.7717 - acc: 0.7645 - val_loss: 0.6595 - val_acc: 0.8014
# Epoch 14/100
# Epoch 00013: val_loss improved from 0.65951 to 0.65028, saving model to final_model.h5
# 760s - loss: 0.7548 - acc: 0.7689 - val_loss: 0.6503 - val_acc: 0.8036
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 748s - loss: 0.7420 - acc: 0.7723 - val_loss: 0.6601 - val_acc: 0.8007
# Epoch 16/100
# Epoch 00015: val_loss improved from 0.65028 to 0.61693, saving model to final_model.h5
# 748s - loss: 0.7257 - acc: 0.7762 - val_loss: 0.6169 - val_acc: 0.8133
# Epoch 17/100
# Epoch 00016: val_loss improved from 0.61693 to 0.60338, saving model to final_model.h5
# 748s - loss: 0.7106 - acc: 0.7804 - val_loss: 0.6034 - val_acc: 0.8164
# Epoch 18/100
# Epoch 00017: val_loss improved from 0.60338 to 0.58312, saving model to final_model.h5
# 755s - loss: 0.6957 - acc: 0.7841 - val_loss: 0.5831 - val_acc: 0.8231
# Epoch 19/100
# Epoch 00018: val_loss improved from 0.58312 to 0.56779, saving model to final_model.h5
# 752s - loss: 0.6833 - acc: 0.7876 - val_loss: 0.5678 - val_acc: 0.8283
# Epoch 20/100
# Epoch 00019: val_loss improved from 0.56779 to 0.55607, saving model to final_model.h5
# 748s - loss: 0.6692 - acc: 0.7915 - val_loss: 0.5561 - val_acc: 0.8319
# Epoch 21/100
# Epoch 00020: val_loss improved from 0.55607 to 0.54813, saving model to final_model.h5
# 760s - loss: 0.6588 - acc: 0.7944 - val_loss: 0.5481 - val_acc: 0.8353
# Epoch 22/100
# Epoch 00021: val_loss improved from 0.54813 to 0.52489, saving model to final_model.h5
# 768s - loss: 0.6436 - acc: 0.7993 - val_loss: 0.5249 - val_acc: 0.8412
# Epoch 23/100
# Epoch 00022: val_loss improved from 0.52489 to 0.51923, saving model to final_model.h5
# 752s - loss: 0.6302 - acc: 0.8028 - val_loss: 0.5192 - val_acc: 0.8426
# Epoch 24/100
# Epoch 00023: val_loss improved from 0.51923 to 0.49918, saving model to final_model.h5
# 749s - loss: 0.6199 - acc: 0.8058 - val_loss: 0.4992 - val_acc: 0.8527
# Epoch 25/100
# Epoch 00024: val_loss improved from 0.49918 to 0.49309, saving model to final_model.h5
# 751s - loss: 0.6079 - acc: 0.8090 - val_loss: 0.4931 - val_acc: 0.8527
# Epoch 26/100
# Epoch 00025: val_loss improved from 0.49309 to 0.48430, saving model to final_model.h5
# 753s - loss: 0.5991 - acc: 0.8114 - val_loss: 0.4843 - val_acc: 0.8541
# Epoch 27/100
# Epoch 00026: val_loss improved from 0.48430 to 0.47410, saving model to final_model.h5
# 748s - loss: 0.5889 - acc: 0.8146 - val_loss: 0.4741 - val_acc: 0.8570
# Epoch 28/100
# Epoch 00027: val_loss improved from 0.47410 to 0.45866, saving model to final_model.h5
# 751s - loss: 0.5774 - acc: 0.8178 - val_loss: 0.4587 - val_acc: 0.8629
# Epoch 29/100
# Epoch 00028: val_loss improved from 0.45866 to 0.44489, saving model to final_model.h5
# 751s - loss: 0.5669 - acc: 0.8207 - val_loss: 0.4449 - val_acc: 0.8661
# Epoch 30/100
# Epoch 00029: val_loss improved from 0.44489 to 0.43683, saving model to final_model.h5
# 753s - loss: 0.5555 - acc: 0.8239 - val_loss: 0.4368 - val_acc: 0.8709
# Epoch 31/100
# Epoch 00030: val_loss improved from 0.43683 to 0.42641, saving model to final_model.h5
# 747s - loss: 0.5456 - acc: 0.8264 - val_loss: 0.4264 - val_acc: 0.8729
# Epoch 32/100
# Epoch 00031: val_loss improved from 0.42641 to 0.41558, saving model to final_model.h5
# 749s - loss: 0.5367 - acc: 0.8289 - val_loss: 0.4156 - val_acc: 0.8747
# Epoch 33/100
# Epoch 00032: val_loss improved from 0.41558 to 0.40460, saving model to final_model.h5
# 755s - loss: 0.5280 - acc: 0.8314 - val_loss: 0.4046 - val_acc: 0.8781
# Epoch 34/100
# Epoch 00033: val_loss improved from 0.40460 to 0.40179, saving model to final_model.h5
# 752s - loss: 0.5187 - acc: 0.8341 - val_loss: 0.4018 - val_acc: 0.8780
# Epoch 35/100
# Epoch 00034: val_loss improved from 0.40179 to 0.38982, saving model to final_model.h5
# 749s - loss: 0.5060 - acc: 0.8374 - val_loss: 0.3898 - val_acc: 0.8806
# Epoch 36/100
# Epoch 00035: val_loss improved from 0.38982 to 0.37686, saving model to final_model.h5
# 747s - loss: 0.5010 - acc: 0.8387 - val_loss: 0.3769 - val_acc: 0.8871
# Epoch 37/100
# Epoch 00036: val_loss improved from 0.37686 to 0.37182, saving model to final_model.h5
# 753s - loss: 0.4905 - acc: 0.8416 - val_loss: 0.3718 - val_acc: 0.8875
# Epoch 38/100
# Epoch 00037: val_loss improved from 0.37182 to 0.36223, saving model to final_model.h5
# 754s - loss: 0.4825 - acc: 0.8439 - val_loss: 0.3622 - val_acc: 0.8900
# Epoch 39/100
# Epoch 00038: val_loss improved from 0.36223 to 0.35430, saving model to final_model.h5
# 748s - loss: 0.4741 - acc: 0.8463 - val_loss: 0.3543 - val_acc: 0.8913
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 748s - loss: 0.4696 - acc: 0.8472 - val_loss: 0.3575 - val_acc: 0.8887
# Epoch 41/100
# Epoch 00040: val_loss improved from 0.35430 to 0.34812, saving model to final_model.h5
# 752s - loss: 0.4634 - acc: 0.8491 - val_loss: 0.3481 - val_acc: 0.8932
# Epoch 42/100
# Epoch 00041: val_loss improved from 0.34812 to 0.33580, saving model to final_model.h5
# 752s - loss: 0.4548 - acc: 0.8517 - val_loss: 0.3358 - val_acc: 0.8973
# Epoch 43/100
# Epoch 00042: val_loss improved from 0.33580 to 0.33512, saving model to final_model.h5
# 776s - loss: 0.4464 - acc: 0.8544 - val_loss: 0.3351 - val_acc: 0.8975
# Epoch 44/100
# Epoch 00043: val_loss improved from 0.33512 to 0.32666, saving model to final_model.h5
# 756s - loss: 0.4414 - acc: 0.8555 - val_loss: 0.3267 - val_acc: 0.8993
# Epoch 45/100
# Epoch 00044: val_loss improved from 0.32666 to 0.31960, saving model to final_model.h5
# 816s - loss: 0.4325 - acc: 0.8585 - val_loss: 0.3196 - val_acc: 0.9016
# Epoch 46/100
# Epoch 00045: val_loss improved from 0.31960 to 0.31077, saving model to final_model.h5
# 1017s - loss: 0.4270 - acc: 0.8599 - val_loss: 0.3108 - val_acc: 0.9028
# Epoch 47/100
# Epoch 00046: val_loss improved from 0.31077 to 0.30527, saving model to final_model.h5
# 870s - loss: 0.4217 - acc: 0.8617 - val_loss: 0.3053 - val_acc: 0.9055
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 879s - loss: 0.4185 - acc: 0.8619 - val_loss: 0.3117 - val_acc: 0.9034
# Epoch 49/100
# Epoch 00048: val_loss improved from 0.30527 to 0.29549, saving model to final_model.h5
# 914s - loss: 0.4132 - acc: 0.8640 - val_loss: 0.2955 - val_acc: 0.9086
# Epoch 50/100
# Epoch 00049: val_loss improved from 0.29549 to 0.29403, saving model to final_model.h5
# 907s - loss: 0.4051 - acc: 0.8668 - val_loss: 0.2940 - val_acc: 0.9099
# Epoch 51/100
# Epoch 00050: val_loss improved from 0.29403 to 0.29167, saving model to final_model.h5
# 853s - loss: 0.4005 - acc: 0.8682 - val_loss: 0.2917 - val_acc: 0.9098
# Epoch 52/100
# Epoch 00051: val_loss improved from 0.29167 to 0.28117, saving model to final_model.h5
# 864s - loss: 0.3957 - acc: 0.8698 - val_loss: 0.2812 - val_acc: 0.9141
# Epoch 53/100
# Epoch 00052: val_loss improved from 0.28117 to 0.27984, saving model to final_model.h5
# 900s - loss: 0.3916 - acc: 0.8707 - val_loss: 0.2798 - val_acc: 0.9141
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 914s - loss: 0.3876 - acc: 0.8720 - val_loss: 0.2818 - val_acc: 0.9123
# Epoch 55/100
# Epoch 00054: val_loss improved from 0.27984 to 0.26772, saving model to final_model.h5
# 944s - loss: 0.3828 - acc: 0.8737 - val_loss: 0.2677 - val_acc: 0.9195
# Epoch 56/100
# Epoch 00055: val_loss improved from 0.26772 to 0.26603, saving model to final_model.h5
# 980s - loss: 0.3765 - acc: 0.8760 - val_loss: 0.2660 - val_acc: 0.9192
# Epoch 57/100
# Epoch 00056: val_loss improved from 0.26603 to 0.26566, saving model to final_model.h5
# 1335s - loss: 0.3710 - acc: 0.8778 - val_loss: 0.2657 - val_acc: 0.9177
# Epoch 58/100
# Epoch 00057: val_loss improved from 0.26566 to 0.25997, saving model to final_model.h5
# 1021s - loss: 0.3686 - acc: 0.8779 - val_loss: 0.2600 - val_acc: 0.9206
# Epoch 59/100
# Epoch 00058: val_loss improved from 0.25997 to 0.25657, saving model to final_model.h5
# 914s - loss: 0.3671 - acc: 0.8786 - val_loss: 0.2566 - val_acc: 0.9225
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 964s - loss: 0.3604 - acc: 0.8812 - val_loss: 0.2581 - val_acc: 0.9224
# Epoch 61/100
# Epoch 00060: val_loss improved from 0.25657 to 0.25295, saving model to final_model.h5
# 1098s - loss: 0.3547 - acc: 0.8830 - val_loss: 0.2530 - val_acc: 0.9213
# Epoch 62/100
# Epoch 00061: val_loss improved from 0.25295 to 0.24533, saving model to final_model.h5
# 1139s - loss: 0.3534 - acc: 0.8832 - val_loss: 0.2453 - val_acc: 0.9251
# Epoch 63/100
# Epoch 00062: val_loss improved from 0.24533 to 0.24314, saving model to final_model.h5
# 993s - loss: 0.3492 - acc: 0.8845 - val_loss: 0.2431 - val_acc: 0.9258
# Epoch 64/100
# Epoch 00063: val_loss improved from 0.24314 to 0.23863, saving model to final_model.h5
# 970s - loss: 0.3453 - acc: 0.8861 - val_loss: 0.2386 - val_acc: 0.9276
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 1043s - loss: 0.3424 - acc: 0.8868 - val_loss: 0.2412 - val_acc: 0.9249
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 989s - loss: 0.3379 - acc: 0.8881 - val_loss: 0.2405 - val_acc: 0.9267
# Epoch 67/100
# Epoch 00066: val_loss improved from 0.23863 to 0.23159, saving model to final_model.h5
# 935s - loss: 0.3347 - acc: 0.8894 - val_loss: 0.2316 - val_acc: 0.9289
# Epoch 68/100
# Epoch 00067: val_loss improved from 0.23159 to 0.23068, saving model to final_model.h5
# 968s - loss: 0.3338 - acc: 0.8894 - val_loss: 0.2307 - val_acc: 0.9291
# Epoch 69/100
# Epoch 00068: val_loss improved from 0.23068 to 0.22934, saving model to final_model.h5
# 1377s - loss: 0.3277 - acc: 0.8917 - val_loss: 0.2293 - val_acc: 0.9300
# Epoch 70/100
# Epoch 00069: val_loss improved from 0.22934 to 0.22341, saving model to final_model.h5
# 1129s - loss: 0.3264 - acc: 0.8921 - val_loss: 0.2234 - val_acc: 0.9324
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 1079s - loss: 0.3219 - acc: 0.8937 - val_loss: 0.2321 - val_acc: 0.9277
# Epoch 72/100
# Epoch 00071: val_loss improved from 0.22341 to 0.22310, saving model to final_model.h5
# 1006s - loss: 0.3186 - acc: 0.8946 - val_loss: 0.2231 - val_acc: 0.9311
# Epoch 73/100
# Epoch 00072: val_loss improved from 0.22310 to 0.21440, saving model to final_model.h5
# 992s - loss: 0.3171 - acc: 0.8955 - val_loss: 0.2144 - val_acc: 0.9347
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 988s - loss: 0.3131 - acc: 0.8967 - val_loss: 0.2272 - val_acc: 0.9315
# Epoch 75/100
# Epoch 00074: val_loss improved from 0.21440 to 0.21016, saving model to final_model.h5
# 1215s - loss: 0.3104 - acc: 0.8974 - val_loss: 0.2102 - val_acc: 0.9367
# Epoch 76/100
# Epoch 00075: val_loss improved from 0.21016 to 0.21006, saving model to final_model.h5
# 1023s - loss: 0.3105 - acc: 0.8974 - val_loss: 0.2101 - val_acc: 0.9366
# Epoch 77/100
# Epoch 00076: val_loss improved from 0.21006 to 0.20551, saving model to final_model.h5
# 993s - loss: 0.3056 - acc: 0.8992 - val_loss: 0.2055 - val_acc: 0.9370
# Epoch 78/100
# Epoch 00077: val_loss improved from 0.20551 to 0.20482, saving model to final_model.h5
# 1004s - loss: 0.3047 - acc: 0.8991 - val_loss: 0.2048 - val_acc: 0.9374
# Epoch 79/100
# Epoch 00078: val_loss improved from 0.20482 to 0.20432, saving model to final_model.h5
# 1031s - loss: 0.3010 - acc: 0.9006 - val_loss: 0.2043 - val_acc: 0.9375
# Epoch 80/100
# Epoch 00079: val_loss improved from 0.20432 to 0.20238, saving model to final_model.h5
# 963s - loss: 0.2993 - acc: 0.9012 - val_loss: 0.2024 - val_acc: 0.9381
# Epoch 81/100
# Epoch 00080: val_loss improved from 0.20238 to 0.20044, saving model to final_model.h5
# 977s - loss: 0.2965 - acc: 0.9022 - val_loss: 0.2004 - val_acc: 0.9393
# Epoch 82/100
# Epoch 00081: val_loss improved from 0.20044 to 0.19993, saving model to final_model.h5
# 987s - loss: 0.2945 - acc: 0.9030 - val_loss: 0.1999 - val_acc: 0.9389
# Epoch 83/100
# Epoch 00082: val_loss improved from 0.19993 to 0.19314, saving model to final_model.h5
# 960s - loss: 0.2897 - acc: 0.9049 - val_loss: 0.1931 - val_acc: 0.9417
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 1113s - loss: 0.2904 - acc: 0.9045 - val_loss: 0.1998 - val_acc: 0.9392
# Epoch 85/100
# Epoch 00084: val_loss improved from 0.19314 to 0.19020, saving model to final_model.h5
# 958s - loss: 0.2865 - acc: 0.9062 - val_loss: 0.1902 - val_acc: 0.9427
# Epoch 86/100
# Epoch 00085: val_loss improved from 0.19020 to 0.18919, saving model to final_model.h5
# 977s - loss: 0.2868 - acc: 0.9055 - val_loss: 0.1892 - val_acc: 0.9430
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 983s - loss: 0.2834 - acc: 0.9073 - val_loss: 0.1927 - val_acc: 0.9423
# Epoch 88/100
# Epoch 00087: val_loss improved from 0.18919 to 0.18544, saving model to final_model.h5
# 1036s - loss: 0.2784 - acc: 0.9090 - val_loss: 0.1854 - val_acc: 0.9445
# Epoch 89/100
# Epoch 00088: val_loss improved from 0.18544 to 0.18333, saving model to final_model.h5
# 951s - loss: 0.2747 - acc: 0.9104 - val_loss: 0.1833 - val_acc: 0.9462
# Epoch 90/100
# Epoch 00089: val_loss improved from 0.18333 to 0.18327, saving model to final_model.h5
# 1102s - loss: 0.2760 - acc: 0.9102 - val_loss: 0.1833 - val_acc: 0.9449
# Epoch 91/100
# Epoch 00090: val_loss improved from 0.18327 to 0.18059, saving model to final_model.h5
# 1091s - loss: 0.2729 - acc: 0.9112 - val_loss: 0.1806 - val_acc: 0.9464
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 971s - loss: 0.2730 - acc: 0.9109 - val_loss: 0.1816 - val_acc: 0.9462
# Epoch 93/100
# Epoch 00092: val_loss improved from 0.18059 to 0.18055, saving model to final_model.h5
# 1075s - loss: 0.2698 - acc: 0.9121 - val_loss: 0.1805 - val_acc: 0.9460
# Epoch 94/100
# Epoch 00093: val_loss improved from 0.18055 to 0.17691, saving model to final_model.h5
# 928s - loss: 0.2677 - acc: 0.9129 - val_loss: 0.1769 - val_acc: 0.9473
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 941s - loss: 0.2660 - acc: 0.9132 - val_loss: 0.1775 - val_acc: 0.9470
# Epoch 96/100
# Epoch 00095: val_loss improved from 0.17691 to 0.17458, saving model to final_model.h5
# 935s - loss: 0.2641 - acc: 0.9141 - val_loss: 0.1746 - val_acc: 0.9479
# Epoch 97/100
# Epoch 00096: val_loss improved from 0.17458 to 0.17066, saving model to final_model.h5
# 861s - loss: 0.2626 - acc: 0.9145 - val_loss: 0.1707 - val_acc: 0.9495
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 902s - loss: 0.2648 - acc: 0.9137 - val_loss: 0.1826 - val_acc: 0.9453
# Epoch 99/100
# Epoch 00098: val_loss improved from 0.17066 to 0.16965, saving model to final_model.h5
# 943s - loss: 0.2607 - acc: 0.9153 - val_loss: 0.1697 - val_acc: 0.9499
# Epoch 100/100
# Epoch 00099: val_loss improved from 0.16965 to 0.16780, saving model to final_model.h5
# 950s - loss: 0.2573 - acc: 0.9163 - val_loss: 0.1678 - val_acc: 0.9502
# new jersey est parfois calme à l'automne de il est est en en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Sample 1:
# il a vu un vieux camion jaune <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Il a vu un vieux camion jaune
# Sample 2:
# new jersey est parfois calme à l'automne de il est est en en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ## Submission
# When you are ready to submit your project, do the following steps:
# 1. Ensure you pass all points on the [rubric](https://review.udacity.com/#!/rubrics/1004/view).
# 2. Submit the following in a zip file.
#   - `helper.py`
#   - `machine_translation.ipynb`
#   - `machine_translation.html`
#     - You can export the notebook by navigating to **File -> Download as -> HTML (.html)**.
